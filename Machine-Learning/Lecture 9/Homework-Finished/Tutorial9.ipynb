# %% [markdown]
# **Name:** SHUYUE JIA
#
# **EID:** 56846018

# %% [markdown]
# # CS5489 - Tutorial 9
# ## Face Detection with CNNs
#
# In the previous tutorial, you used an MLP to detect a face in a small image patch.
# In this tutorial you will train a CNN instead of an MLP.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import os
import zipfile
import fnmatch
random.seed(100)
import skimage.io
import skimage.color
import skimage.transform
from scipy import ndimage

# %% [markdown]
# Next we will load keras and tensorflow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import struct
K.set_image_data_format('channels_last')
print(keras.__version__, tf.__version__)
# Out:
# 2.2.4-tf 1.14.0

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the images.  Download `faces.zip`, and place it in the same directory as this ipynb file.  **Do not unzip it.** Then run the following cell to load the images.

# %%
imgdata = {'train':[], 'test':[]}
classes = {'train':[], 'test':[]}

# the dataset is too big, so subsample the training and test sets...
# reduce training set by a factor of 4
train_subsample = 1
train_counter = [0, 0]
# maximum number of samples in each class for test set
test_maxsample = 472
test_counter = [0, 0]

# load the zip file
filename = 'faces.zip'
zfile = zipfile.ZipFile(filename, 'r')

for name in zfile.namelist():
    # check file name matches
    if fnmatch.fnmatch(name, "faces/*/*/*.png"):
        
        # filename is : faces/train/face/fname.png
        (fdir1, fname)  = os.path.split(name)     # get file name
        (fdir2, fclass) = os.path.split(fdir1) # get class (face, nonface)
        (fdir3, fset)   = os.path.split(fdir2) # get training/test set
        # class 1 = face; class 0 = non-face
        myclass = int(fclass == "face")  

        loadme = False
        if fset == 'train':
            if (train_counter[myclass] % train_subsample) == 0:
                loadme = True
            train_counter[myclass] += 1
        elif fset == 'test':
            if test_counter[myclass] < test_maxsample:
                loadme = True
            test_counter[myclass] += 1
            
        if (loadme):
            # open file in memory, and parse as an image
            myfile = zfile.open(name)
            img = matplotlib.image.imread(myfile)
            # img = skimage.io.imread(myfile)
            # convert to grayscale
            img = skimage.color.rgb2gray(img)
            myfile.close()
            
            # append data
            imgdata[fset].append(img)
            classes[fset].append(myclass)

        
zfile.close()
imgsize = img.shape

print(len(imgdata['train']))
print(len(imgdata['test']))
trainclass2start = sum(classes['train'])
# Out:
# 6977
# 944

# %% [markdown]
# Next we will convert the list of images into a block (array) of images for easier processing.

# %%
# convert list to numpy array
trainY = asarray(classes['train'])
testY  = asarray(classes['test'])

# convert class labels to binary indicators
trainYb = keras.utils.to_categorical(trainY)
testYb  = keras.utils.to_categorical(testY)

# convert list of ndarray to ndarray
trainI = asarray(imgdata['train']).reshape((6977,19,19,1))
testI  = asarray(imgdata['test']).reshape((944,19,19,1))

# cleanup memory
del imgdata

# shuffle the data (since it is in order by class)
random.seed(123)
inds1 = random.permutation(len(trainI)).tolist()
inds2 = random.permutation(len(testI)).tolist()
trainYb = trainYb[inds1]
testYb  = testYb[inds2]
trainY = trainY[inds1]
testY  = testY[inds2]
trainI = trainI[inds1]
testI = testI[inds2]

print(trainI.shape)
print(testI.shape)
# Out:
# (6977, 19, 19, 1)
# (944, 19, 19, 1)

# %% [markdown]
# Each image is a 19x19x1 array of pixel values.  The last dimension is the number of channels in the image - in this case the image is grayscale, so there is only 1 channel.  Run the below code to show an example:

# %%
print(img.shape)
plt.subplot(1,2,1)
plt.imshow(squeeze(trainI[1]), cmap='gray', interpolation='nearest')
plt.title("face sample")
plt.subplot(1,2,2)
plt.imshow(squeeze(trainI[2]), cmap='gray', interpolation='nearest')
plt.title("non-face sample")
plt.show()
# Out:
# (19, 19)

# %% [markdown]
# Run the below code to show more images!

# %%
# function to make an image montage
def image_montage(X, imsize=None, maxw=10):
    """X can be a list of images, or a matrix of vectorized images.
      Specify imsize when X is a matrix."""
    tmp = []
    numimgs = len(X)
    
    # create a list of images (reshape if necessary)
    for i in range(0,numimgs):
        if imsize != None:
            tmp.append(X[i].reshape(imsize))
        else:
            tmp.append(squeeze(X[i]))
    
    # add blanks
    if (numimgs > maxw) and (mod(numimgs, maxw) > 0):
        leftover = maxw - mod(numimgs, maxw)
        meanimg = 0.5*(X[0].max()+X[0].min())
        for i in range(0,leftover):
            tmp.append(ones(tmp[0].shape)*meanimg)
    
    # make the montage
    tmp2 = []
    for i in range(0,len(tmp),maxw):
        tmp2.append( hstack(tmp[i:i+maxw]) )
    montimg = vstack(tmp2) 
    return montimg

# show images in a plot
def show_imgs(W_list, nc=10, highlight_green=None, highlight_red=None, titles=None):
    # nc is the number of columns
    nfilter = len(W_list)
    nr = (nfilter - 1) // nc + 1
    for i in range(nr):
        for j in range(nc):
            idx = i * nc + j
            if idx == nfilter:
                break
            plt.subplot(nr, nc, idx + 1)
            cur_W = W_list[idx]
            plt.imshow(cur_W,cmap='gray', interpolation='nearest')  
            if titles is not None:
                if isinstance(titles, str):
                    plt.title(titles.format(idx))
                else:
                    plt.title(titles[idx])
            
            if ((highlight_green is not None) and highlight_green[idx]) or \
               ((highlight_red is not None) and highlight_red[idx]): 
                ax = plt.gca()
                if highlight_green[idx]:
                    mycol = '#00FF00'
                else:
                    mycol = 'r'
                for S in ['bottom', 'top', 'right', 'left']:
                    ax.spines[S].set_color(mycol)
                    ax.spines[S].set_lw(2.0)
                ax.xaxis.set_ticks_position('none')               
                ax.yaxis.set_ticks_position('none')
                ax.set_xticks([])
                ax.set_yticks([])
            else:
                plt.gca().set_axis_off()

# show a few images
plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,0]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,1]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

# %% [markdown]
# Next we will generate the training/validation set from the training data.

# %%
# generate fixed validation set of 10% of the training set
vtrainI, validI, vtrainYb, validYb = \
  model_selection.train_test_split(trainI, trainYb, 
  train_size=0.9, test_size=0.1, random_state=4488)

# make validation data
validsetI = (validI, validYb)

print(vtrainI.shape)
print(validI.shape)
# Out:
# (6279, 19, 19, 1)
# (698, 19, 19, 1)

# %% [markdown]
# Here are some useful functions.

# %%
# compatible with v1 or v2
def tf_compat():
    if tf.__version__[0] == '1':
        return (tf.set_random_seed, 'acc')
    else:
        return (tf.random.set_seed, 'accuracy')
    
tf_set_seed, accname = tf_compat()

def plot_history(history): 
    fig, ax1 = plt.subplots()
    
    ax1.plot(history.history['loss'], 'r', label="training loss ({:.6f})".format(history.history['loss'][-1]))
    ax1.plot(history.history['val_loss'], 'r--', label="validation loss ({:.6f})".format(history.history['val_loss'][-1]))
    ax1.grid(True)
    ax1.set_xlabel('iteration')
    ax1.legend(loc="best", fontsize=9)    
    ax1.set_ylabel('loss', color='r')
    ax1.tick_params('y', colors='r')

    if accname in history.history:
        ax2 = ax1.twinx()

        ax2.plot(history.history[accname], 'b', label="training acc ({:.4f})".format(history.history[accname][-1]))
        ax2.plot(history.history['val_'+accname], 'b--', label="validation acc ({:.4f})".format(history.history['val_'+accname][-1]))

        ax2.legend(loc="best", fontsize=9)
        ax2.set_ylabel('acc', color='b')        
        ax2.tick_params('y', colors='b')

# %% [markdown]
# Now let's try a simple logistic regression classifier, trained using Keras. Since the inputs are images, we will convert the input image into a vector using the "Flatten" layer first.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00013: early stopping
# test accuracy: 0.5603813559322034

# %% [markdown]
# ## 2. Detection using CNN
#
# Train an CNN to classify an image patch as face or not face.  Use  `vtrainI` and `vtrainY` as the training set and `validsetI` as the validation set.  You can try different architectures, and adjust values of the learning rates, number of iterations, early stopping, regularization, etc. to get a good result.  Use a large batch size (e.g., 50) to speed up the training time.  Remember to add the `callbacks` so that you can monitor the training process.

# %%
# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), # channel, kernel size, stride
activation='relu', padding='same', input_shape=(19, 19, 1)))
nn.add(Flatten()) # flatten the feature map into a vector to apply Dense layers 
nn.add(Dense(units=50, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
    monitor='val_' + accname,
    min_delta=0.0001, 
    patience=5, 
    verbose=1, 
    mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])

history = nn.fit(vtrainI, 
                 vtrainYb, 
                 epochs=100, 
                 batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00015: early stopping
# test accuracy: 0.5985169491525424

# %%
# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
    monitor='val_' + accname,
    min_delta=0.0001, 
    patience=5, 
    verbose=1, 
    mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy'])

history = nn.fit(vtrainI, 
                 vtrainYb, 
                 epochs=100, 
                 batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00015: early stopping
# test accuracy: 0.663135593220339

# %% [markdown]
# _How does the CNN compare to the linear and non-linear classifiers that you tried in Tutorial 4?_
# - The performances of CNN are superior than non-linear classifier in Tutorial 4.

# %% [markdown]
# ## 3. Data Augmentation
#
# Now use data augmentation (introduced in the last tutorial) to try to improve the accuracy.

# %% [markdown]
# We can also add per-pixel noise or transformations. We define a few functions for adding per-pixel noise.  The following functions will add Gaussian pixel noise, add corruption noise (setting some input pixels to 0), scale and shift pixel values (changing contrast and brightness).

# %%
def add_gauss_noise(X, sigma2=0.05):
    # add Gaussian noise with zero mean, and variance sigma2
    return X + random.normal(0, sigma2, X.shape)

def add_corrupt_noise(X, p=0.1):
    # apply pixel corruption (zero out value) with probability p
    return X * random.binomial(1, 1-p, X.shape)

def add_scale_shift(X, sigma2=0.1, alpha2=0.2):
    # randomly scale and shift the pixel values (same for each image)
    # Xnew = a X + b
    # a is sampled from a Gaussian with mean 1, and variance sigma2
    # b is sampled from a Gaussian with mean 0, and variance alpha2
    if X.ndim == 3:
        dshape = (X.shape[0],1,1)
    elif X.ndim == 4:
        dshape = (X.shape[0],1,1,1)
    else:
        dshape = (1,)
    a = random.normal(1,sigma2, dshape)
    b = random.normal(0,alpha2, dshape)
    return minimum(maximum( a*X + b, 0.0), 1.0)

# %% [markdown]
# Next, we define a function for adding per-pixel noise (in this case just Gaussian noise). The noise is included using the `preprocessing_function` input of the `ImageDataGenerator`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

# %% [markdown]
# Next we can show some examples of augmented images. Run the code below to see different random augmentations.

# %%
img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

# %% [markdown]
# The augmented images look similar to the original image, but contain small differences that the network can use to learn more about the class.

# %% [markdown]
# Now let's try training logistic regression with data augmentation. Instead of "fit", we now  use the "fit_generator" method, which will pass each input through the ImageDataGenerator before sending it to the MLP.  We also disable early stopping so that the training sees more augmented data.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
#           callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.2421 - acc: 0.8974 - val_loss: 0.1456 - val_acc: 0.9441
# Epoch 2/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.1888 - acc: 0.9232 - val_loss: 0.2020 - val_acc: 0.9212
# Epoch 3/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.1760 - acc: 0.9312 - val_loss: 0.1421 - val_acc: 0.9413
# Epoch 4/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.1613 - acc: 0.9331 - val_loss: 0.1396 - val_acc: 0.9370
# Epoch 5/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.1676 - acc: 0.9318 - val_loss: 0.1260 - val_acc: 0.9413
# Epoch 6/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.1719 - acc: 0.9330 - val_loss: 0.1689 - val_acc: 0.9269
# Epoch 7/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.1648 - acc: 0.9368 - val_loss: 0.1158 - val_acc: 0.9527
# Epoch 8/50
# 126/125 [==============================] - 5s 38ms/step - loss: 0.1608 - acc: 0.9345 - val_loss: 0.0950 - val_acc: 0.9656
# Epoch 9/50
# 126/125 [==============================] - 5s 38ms/step - loss: 0.1657 - acc: 0.9368 - val_loss: 0.1174 - val_acc: 0.9556
# Epoch 10/50
# 126/125 [==============================] - 5s 39ms/step - loss: 0.1507 - acc: 0.9403 - val_loss: 0.1684 - val_acc: 0.9269
# Epoch 11/50
# 126/125 [==============================] - 4s 36ms/step - loss: 0.1697 - acc: 0.9312 - val_loss: 0.0907 - val_acc: 0.9613
# Epoch 12/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.1605 - acc: 0.9382 - val_loss: 0.2277 - val_acc: 0.9155
# Epoch 13/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1605 - acc: 0.9366 - val_loss: 0.0951 - val_acc: 0.9613
# Epoch 14/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1688 - acc: 0.9320 - val_loss: 0.1191 - val_acc: 0.9513
# Epoch 15/50
# 126/125 [==============================] - 4s 28ms/step - loss: 0.1531 - acc: 0.9384 - val_loss: 0.1123 - val_acc: 0.9513
# Epoch 16/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.1526 - acc: 0.9374 - val_loss: 0.0988 - val_acc: 0.9642
# Epoch 17/50
# 126/125 [==============================] - 5s 37ms/step - loss: 0.1717 - acc: 0.9328 - val_loss: 0.1037 - val_acc: 0.9556
# Epoch 18/50
# 126/125 [==============================] - 4s 35ms/step - loss: 0.1550 - acc: 0.9420 - val_loss: 0.1302 - val_acc: 0.9513
# Epoch 19/50
# 126/125 [==============================] - 5s 37ms/step - loss: 0.1689 - acc: 0.9353 - val_loss: 0.1069 - val_acc: 0.9599
# Epoch 20/50
# 126/125 [==============================] - 5s 42ms/step - loss: 0.1552 - acc: 0.9404 - val_loss: 0.1085 - val_acc: 0.9484
# Epoch 21/50
# 126/125 [==============================] - 4s 28ms/step - loss: 0.1604 - acc: 0.9369 - val_loss: 0.1529 - val_acc: 0.9327
# Epoch 22/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.1674 - acc: 0.9336 - val_loss: 0.1201 - val_acc: 0.9470
# Epoch 23/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.1515 - acc: 0.9401 - val_loss: 0.0940 - val_acc: 0.9685
# Epoch 24/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.1549 - acc: 0.9382 - val_loss: 0.0916 - val_acc: 0.9642
# Epoch 25/50
# 126/125 [==============================] - 5s 36ms/step - loss: 0.1612 - acc: 0.9360 - val_loss: 0.0976 - val_acc: 0.9570
# Epoch 26/50
# 126/125 [==============================] - 5s 39ms/step - loss: 0.1548 - acc: 0.9382 - val_loss: 0.0988 - val_acc: 0.9613
# Epoch 27/50
# 126/125 [==============================] - 4s 36ms/step - loss: 0.1511 - acc: 0.9376 - val_loss: 0.0909 - val_acc: 0.9628
# Epoch 28/50
# 126/125 [==============================] - 4s 35ms/step - loss: 0.1611 - acc: 0.9379 - val_loss: 0.1638 - val_acc: 0.9312
# Epoch 29/50
# 126/125 [==============================] - 5s 38ms/step - loss: 0.1682 - acc: 0.9322 - val_loss: 0.1192 - val_acc: 0.9513
# Epoch 30/50
# 126/125 [==============================] - 4s 36ms/step - loss: 0.1599 - acc: 0.9387 - val_loss: 0.0908 - val_acc: 0.9642
# Epoch 31/50
# 126/125 [==============================] - 4s 34ms/step - loss: 0.1627 - acc: 0.9355 - val_loss: 0.1301 - val_acc: 0.9398
# Epoch 32/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.1505 - acc: 0.9387 - val_loss: 0.1015 - val_acc: 0.9585
# Epoch 33/50
# 126/125 [==============================] - 4s 34ms/step - loss: 0.1531 - acc: 0.9403 - val_loss: 0.1008 - val_acc: 0.9570
# Epoch 34/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.1645 - acc: 0.9349 - val_loss: 0.1321 - val_acc: 0.9413
# Epoch 35/50
# 126/125 [==============================] - 4s 35ms/step - loss: 0.1473 - acc: 0.9411 - val_loss: 0.1169 - val_acc: 0.9441
# Epoch 36/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.1617 - acc: 0.9380 - val_loss: 0.1222 - val_acc: 0.9484
# Epoch 37/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.1488 - acc: 0.9416 - val_loss: 0.0926 - val_acc: 0.9685
# Epoch 38/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1604 - acc: 0.9361 - val_loss: 0.1361 - val_acc: 0.9384
# Epoch 39/50
# 126/125 [==============================] - 4s 34ms/step - loss: 0.1562 - acc: 0.9384 - val_loss: 0.1235 - val_acc: 0.9384
# Epoch 40/50
# 126/125 [==============================] - 4s 28ms/step - loss: 0.1497 - acc: 0.9431 - val_loss: 0.0931 - val_acc: 0.9656
# Epoch 41/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.1498 - acc: 0.9393 - val_loss: 0.0886 - val_acc: 0.9613
# Epoch 42/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.1537 - acc: 0.9425 - val_loss: 0.1838 - val_acc: 0.9241
# Epoch 43/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.1595 - acc: 0.9358 - val_loss: 0.0968 - val_acc: 0.9599
# Epoch 44/50
# 126/125 [==============================] - 3s 26ms/step - loss: 0.1549 - acc: 0.9385 - val_loss: 0.0920 - val_acc: 0.9628
# Epoch 45/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1591 - acc: 0.9385 - val_loss: 0.0969 - val_acc: 0.9542
# Epoch 46/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1606 - acc: 0.9322 - val_loss: 0.0879 - val_acc: 0.9728
# Epoch 47/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1555 - acc: 0.9392 - val_loss: 0.1031 - val_acc: 0.9585
# Epoch 48/50
# 126/125 [==============================] - 3s 26ms/step - loss: 0.1507 - acc: 0.9400 - val_loss: 0.1093 - val_acc: 0.9542
# Epoch 49/50
# 126/125 [==============================] - 3s 26ms/step - loss: 0.1564 - acc: 0.9398 - val_loss: 0.1103 - val_acc: 0.9513
# Epoch 50/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.1542 - acc: 0.9387 - val_loss: 0.0875 - val_acc: 0.9628

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.6800847457627118

# %% [markdown]
# Using data augmentation, the test accuracy improves from 0.622 to 0.692!

# %% [markdown]
# Now train your best CNN from the previous section using data augmentation.
# Try different per-pixel noise levels, and different options of the ImageDataGenerator (see [here](https://keras.io/preprocessing/image/)),
# and combinations of them.  Hopefully you should be able to improve the accuracy!

# %%
# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            #callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 4s 35ms/step - loss: 0.4369 - acc: 0.7887 - val_loss: 0.1814 - val_acc: 0.9355
# Epoch 2/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.1913 - acc: 0.9314 - val_loss: 0.1197 - val_acc: 0.9613
# Epoch 3/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.1572 - acc: 0.9444 - val_loss: 0.1333 - val_acc: 0.9556
# Epoch 4/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.1306 - acc: 0.9586 - val_loss: 0.0906 - val_acc: 0.9713
# Epoch 5/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.1076 - acc: 0.9675 - val_loss: 0.0684 - val_acc: 0.9799
# Epoch 6/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.0973 - acc: 0.9707 - val_loss: 0.0922 - val_acc: 0.9713
# Epoch 7/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0892 - acc: 0.9752 - val_loss: 0.0598 - val_acc: 0.9857
# Epoch 8/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0794 - acc: 0.9771 - val_loss: 0.0606 - val_acc: 0.9814
# Epoch 9/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.0747 - acc: 0.9796 - val_loss: 0.0647 - val_acc: 0.9828
# Epoch 10/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.0686 - acc: 0.9806 - val_loss: 0.0627 - val_acc: 0.9828
# Epoch 11/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0638 - acc: 0.9836 - val_loss: 0.0758 - val_acc: 0.9771
# Epoch 12/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.0630 - acc: 0.9830 - val_loss: 0.0563 - val_acc: 0.9914
# Epoch 13/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.0559 - acc: 0.9849 - val_loss: 0.0408 - val_acc: 0.9928
# Epoch 14/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0575 - acc: 0.9873 - val_loss: 0.0518 - val_acc: 0.9900
# Epoch 15/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.0535 - acc: 0.9865 - val_loss: 0.0516 - val_acc: 0.9871
# Epoch 16/50
# 126/125 [==============================] - 4s 34ms/step - loss: 0.0510 - acc: 0.9895 - val_loss: 0.0404 - val_acc: 0.9928
# Epoch 17/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.0481 - acc: 0.9904 - val_loss: 0.0412 - val_acc: 0.9900
# Epoch 18/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0451 - acc: 0.9904 - val_loss: 0.0414 - val_acc: 0.9928
# Epoch 19/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0454 - acc: 0.9914 - val_loss: 0.0394 - val_acc: 0.9914
# Epoch 20/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0439 - acc: 0.9919 - val_loss: 0.0357 - val_acc: 0.9914
# Epoch 21/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0421 - acc: 0.9922 - val_loss: 0.0327 - val_acc: 0.9943
# Epoch 22/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0447 - acc: 0.9908 - val_loss: 0.0357 - val_acc: 0.9957
# Epoch 23/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.0394 - acc: 0.9928 - val_loss: 0.0359 - val_acc: 0.9928
# Epoch 24/50
# 126/125 [==============================] - 4s 33ms/step - loss: 0.0398 - acc: 0.9930 - val_loss: 0.0380 - val_acc: 0.9943
# Epoch 25/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0391 - acc: 0.9928 - val_loss: 0.0456 - val_acc: 0.9871
# Epoch 26/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.0397 - acc: 0.9927 - val_loss: 0.0282 - val_acc: 1.0000
# Epoch 27/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.0357 - acc: 0.9949 - val_loss: 0.0417 - val_acc: 0.9900
# Epoch 28/50
# 126/125 [==============================] - 4s 31ms/step - loss: 0.0410 - acc: 0.9925 - val_loss: 0.0411 - val_acc: 0.9943
# Epoch 29/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0379 - acc: 0.9935 - val_loss: 0.0316 - val_acc: 0.9957
# Epoch 30/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.0337 - acc: 0.9951 - val_loss: 0.0316 - val_acc: 0.9957
# Epoch 31/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0335 - acc: 0.9946 - val_loss: 0.0344 - val_acc: 0.9943
# Epoch 32/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0326 - acc: 0.9951 - val_loss: 0.0336 - val_acc: 0.9957
# Epoch 33/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.0337 - acc: 0.9936 - val_loss: 0.0378 - val_acc: 0.9957
# Epoch 34/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0338 - acc: 0.9957 - val_loss: 0.0360 - val_acc: 0.9928
# Epoch 35/50
# 126/125 [==============================] - 6s 44ms/step - loss: 0.0328 - acc: 0.9959 - val_loss: 0.0402 - val_acc: 0.9928
# Epoch 36/50
# 126/125 [==============================] - 6s 48ms/step - loss: 0.0322 - acc: 0.9955 - val_loss: 0.0360 - val_acc: 0.9914
# Epoch 37/50
# 126/125 [==============================] - 4s 35ms/step - loss: 0.0343 - acc: 0.9944 - val_loss: 0.0379 - val_acc: 0.9914
# Epoch 38/50
# 126/125 [==============================] - 4s 34ms/step - loss: 0.0279 - acc: 0.9975 - val_loss: 0.0390 - val_acc: 0.9928
# Epoch 39/50
# 126/125 [==============================] - 5s 38ms/step - loss: 0.0313 - acc: 0.9963 - val_loss: 0.0607 - val_acc: 0.9900
# Epoch 40/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0277 - acc: 0.9975 - val_loss: 0.0402 - val_acc: 0.9914
# Epoch 41/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0309 - acc: 0.9959 - val_loss: 0.0302 - val_acc: 0.9971
# Epoch 42/50
# 126/125 [==============================] - 5s 36ms/step - loss: 0.0313 - acc: 0.9970 - val_loss: 0.0388 - val_acc: 0.9928
# Epoch 43/50
# 126/125 [==============================] - 5s 36ms/step - loss: 0.0268 - acc: 0.9973 - val_loss: 0.0262 - val_acc: 0.9971
# Epoch 44/50
# 126/125 [==============================] - 5s 37ms/step - loss: 0.0291 - acc: 0.9960 - val_loss: 0.0460 - val_acc: 0.9914
# Epoch 45/50
# 126/125 [==============================] - 5s 37ms/step - loss: 0.0274 - acc: 0.9971 - val_loss: 0.0355 - val_acc: 0.9957
# Epoch 46/50
# 126/125 [==============================] - 5s 37ms/step - loss: 0.0274 - acc: 0.9978 - val_loss: 0.0359 - val_acc: 0.9928
# Epoch 47/50
# 126/125 [==============================] - 5s 36ms/step - loss: 0.0304 - acc: 0.9967 - val_loss: 0.0347 - val_acc: 0.9943
# Epoch 48/50
# 126/125 [==============================] - 4s 35ms/step - loss: 0.0273 - acc: 0.9973 - val_loss: 0.0318 - val_acc: 0.9957
# Epoch 49/50
# 126/125 [==============================] - 4s 30ms/step - loss: 0.0256 - acc: 0.9981 - val_loss: 0.0383 - val_acc: 0.9928
# Epoch 50/50
# 126/125 [==============================] - 4s 32ms/step - loss: 0.0297 - acc: 0.9970 - val_loss: 0.0387 - val_acc: 0.9943
# test accuracy: 0.8527542372881356

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(rotation_range=10, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.3627 - acc: 0.8417 - val_loss: 0.1624 - val_acc: 0.9513
# Epoch 2/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.1434 - acc: 0.9508 - val_loss: 0.1011 - val_acc: 0.9742
# Epoch 3/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.1049 - acc: 0.9694 - val_loss: 0.0841 - val_acc: 0.9771
# Epoch 4/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0809 - acc: 0.9799 - val_loss: 0.0724 - val_acc: 0.9799
# Epoch 5/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0656 - acc: 0.9853 - val_loss: 0.0639 - val_acc: 0.9857
# Epoch 6/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0538 - acc: 0.9892 - val_loss: 0.0494 - val_acc: 0.9914
# Epoch 7/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0463 - acc: 0.9917 - val_loss: 0.0496 - val_acc: 0.9900
# Epoch 8/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0425 - acc: 0.9925 - val_loss: 0.0343 - val_acc: 0.9957
# Epoch 9/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0380 - acc: 0.9935 - val_loss: 0.0397 - val_acc: 0.9871
# Epoch 10/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0378 - acc: 0.9924 - val_loss: 0.0363 - val_acc: 0.9928
# Epoch 11/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0333 - acc: 0.9954 - val_loss: 0.0323 - val_acc: 0.9971
# Epoch 12/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0280 - acc: 0.9973 - val_loss: 0.0345 - val_acc: 0.9900
# Epoch 13/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0305 - acc: 0.9965 - val_loss: 0.0325 - val_acc: 0.9943
# Epoch 14/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0308 - acc: 0.9962 - val_loss: 0.0304 - val_acc: 0.9957
# Epoch 15/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0240 - acc: 0.9992 - val_loss: 0.0243 - val_acc: 0.9986
# Epoch 16/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.0252 - acc: 0.9976 - val_loss: 0.0294 - val_acc: 0.9971
# Epoch 17/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0245 - acc: 0.9984 - val_loss: 0.0269 - val_acc: 0.9971
# Epoch 18/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0256 - acc: 0.9987 - val_loss: 0.0272 - val_acc: 0.9971
# Epoch 19/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0223 - acc: 0.9990 - val_loss: 0.0323 - val_acc: 0.9943
# Epoch 20/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0214 - acc: 0.9994 - val_loss: 0.0241 - val_acc: 0.9986
# Epoch 00020: early stopping
# test accuracy: 0.6864406779661016

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(width_shift_range=0.05, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 4s 36ms/step - loss: 0.2989 - acc: 0.8700 - val_loss: 0.1282 - val_acc: 0.9513
# Epoch 2/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.1358 - acc: 0.9562 - val_loss: 0.0933 - val_acc: 0.9728
# Epoch 3/50
# 126/125 [==============================] - 3s 26ms/step - loss: 0.1042 - acc: 0.9683 - val_loss: 0.0770 - val_acc: 0.9785
# Epoch 4/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0853 - acc: 0.9760 - val_loss: 0.0571 - val_acc: 0.9857
# Epoch 5/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0657 - acc: 0.9817 - val_loss: 0.0556 - val_acc: 0.9871
# Epoch 6/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0598 - acc: 0.9844 - val_loss: 0.0600 - val_acc: 0.9828
# Epoch 7/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0535 - acc: 0.9889 - val_loss: 0.0390 - val_acc: 0.9900
# Epoch 8/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0416 - acc: 0.9914 - val_loss: 0.0425 - val_acc: 0.9885
# Epoch 9/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0372 - acc: 0.9935 - val_loss: 0.0382 - val_acc: 0.9943
# Epoch 10/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0358 - acc: 0.9941 - val_loss: 0.0402 - val_acc: 0.9928
# Epoch 11/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0350 - acc: 0.9954 - val_loss: 0.0393 - val_acc: 0.9928
# Epoch 12/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0344 - acc: 0.9947 - val_loss: 0.0344 - val_acc: 0.9957
# Epoch 13/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0301 - acc: 0.9967 - val_loss: 0.0294 - val_acc: 0.9971
# Epoch 14/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0287 - acc: 0.9963 - val_loss: 0.0377 - val_acc: 0.9928
# Epoch 15/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0278 - acc: 0.9968 - val_loss: 0.0236 - val_acc: 0.9986
# Epoch 16/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0275 - acc: 0.9970 - val_loss: 0.0255 - val_acc: 0.9986
# Epoch 17/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0234 - acc: 0.9990 - val_loss: 0.0250 - val_acc: 0.9986
# Epoch 18/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0244 - acc: 0.9989 - val_loss: 0.0430 - val_acc: 0.9914
# Epoch 19/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.0231 - acc: 0.9986 - val_loss: 0.0321 - val_acc: 0.9971
# Epoch 20/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.0234 - acc: 0.9989 - val_loss: 0.0302 - val_acc: 0.9971
# Epoch 00020: early stopping
# test accuracy: 0.7690677966101694

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(height_shift_range=0.05, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.3706 - acc: 0.8366 - val_loss: 0.1641 - val_acc: 0.9427
# Epoch 2/50
# 126/125 [==============================] - 2s 19ms/step - loss: 0.1299 - acc: 0.9591 - val_loss: 0.0944 - val_acc: 0.9785
# Epoch 3/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0895 - acc: 0.9734 - val_loss: 0.0796 - val_acc: 0.9828
# Epoch 4/50
# 126/125 [==============================] - 2s 19ms/step - loss: 0.0766 - acc: 0.9787 - val_loss: 0.0652 - val_acc: 0.9828
# Epoch 5/50
# 126/125 [==============================] - 2s 19ms/step - loss: 0.0601 - acc: 0.9850 - val_loss: 0.0505 - val_acc: 0.9885
# Epoch 6/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.0527 - acc: 0.9893 - val_loss: 0.0492 - val_acc: 0.9857
# Epoch 7/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0489 - acc: 0.9896 - val_loss: 0.0629 - val_acc: 0.9857
# Epoch 8/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0390 - acc: 0.9933 - val_loss: 0.0428 - val_acc: 0.9900
# Epoch 9/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.0347 - acc: 0.9952 - val_loss: 0.0411 - val_acc: 0.9914
# Epoch 10/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.0306 - acc: 0.9963 - val_loss: 0.0335 - val_acc: 0.9957
# Epoch 11/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0287 - acc: 0.9963 - val_loss: 0.0379 - val_acc: 0.9928
# Epoch 12/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0286 - acc: 0.9968 - val_loss: 0.0405 - val_acc: 0.9914
# Epoch 13/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0242 - acc: 0.9990 - val_loss: 0.0318 - val_acc: 0.9971
# Epoch 14/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0248 - acc: 0.9978 - val_loss: 0.0423 - val_acc: 0.9914
# Epoch 15/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0236 - acc: 0.9987 - val_loss: 0.0401 - val_acc: 0.9928
# Epoch 16/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0213 - acc: 0.9995 - val_loss: 0.0385 - val_acc: 0.9900
# Epoch 17/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0219 - acc: 0.9992 - val_loss: 0.0336 - val_acc: 0.9928
# Epoch 18/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0230 - acc: 0.9990 - val_loss: 0.0299 - val_acc: 0.9971
# Epoch 00018: early stopping
# test accuracy: 0.7436440677966102

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(shear_range=0.05, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.3353 - acc: 0.8511 - val_loss: 0.1503 - val_acc: 0.9484
# Epoch 2/50
# 126/125 [==============================] - 2s 14ms/step - loss: 0.1095 - acc: 0.9656 - val_loss: 0.1107 - val_acc: 0.9685
# Epoch 3/50
# 126/125 [==============================] - 2s 19ms/step - loss: 0.0766 - acc: 0.9807 - val_loss: 0.0658 - val_acc: 0.9871
# Epoch 4/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0607 - acc: 0.9858 - val_loss: 0.0544 - val_acc: 0.9885
# Epoch 5/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0497 - acc: 0.9876 - val_loss: 0.0494 - val_acc: 0.9900
# Epoch 6/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0407 - acc: 0.9935 - val_loss: 0.0435 - val_acc: 0.9914
# Epoch 7/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0354 - acc: 0.9951 - val_loss: 0.0498 - val_acc: 0.9885
# Epoch 8/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0295 - acc: 0.9970 - val_loss: 0.0420 - val_acc: 0.9928
# Epoch 9/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0267 - acc: 0.9979 - val_loss: 0.0436 - val_acc: 0.9885
# Epoch 10/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0234 - acc: 0.9997 - val_loss: 0.0380 - val_acc: 0.9914
# Epoch 11/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0224 - acc: 0.9997 - val_loss: 0.0408 - val_acc: 0.9928
# Epoch 12/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0213 - acc: 0.9995 - val_loss: 0.0359 - val_acc: 0.9943
# Epoch 13/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0205 - acc: 1.0000 - val_loss: 0.0366 - val_acc: 0.9928
# Epoch 14/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0197 - acc: 1.0000 - val_loss: 0.0383 - val_acc: 0.9943
# Epoch 15/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0194 - acc: 1.0000 - val_loss: 0.0365 - val_acc: 0.9943
# Epoch 16/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0191 - acc: 1.0000 - val_loss: 0.0357 - val_acc: 0.9928
# Epoch 17/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0190 - acc: 1.0000 - val_loss: 0.0355 - val_acc: 0.9928
# Epoch 00017: early stopping
# test accuracy: 0.638771186440678

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(zoom_range=0.05, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.3602 - acc: 0.8239 - val_loss: 0.1296 - val_acc: 0.9527
# Epoch 2/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.1183 - acc: 0.9624 - val_loss: 0.0873 - val_acc: 0.9785
# Epoch 3/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0899 - acc: 0.9726 - val_loss: 0.0651 - val_acc: 0.9842
# Epoch 4/50
# 126/125 [==============================] - 2s 19ms/step - loss: 0.0677 - acc: 0.9831 - val_loss: 0.0535 - val_acc: 0.9900
# Epoch 5/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0536 - acc: 0.9877 - val_loss: 0.0593 - val_acc: 0.9857
# Epoch 6/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0410 - acc: 0.9930 - val_loss: 0.0426 - val_acc: 0.9928
# Epoch 7/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0365 - acc: 0.9938 - val_loss: 0.0426 - val_acc: 0.9885
# Epoch 8/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0318 - acc: 0.9962 - val_loss: 0.0492 - val_acc: 0.9842
# Epoch 9/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0289 - acc: 0.9965 - val_loss: 0.0571 - val_acc: 0.9885
# Epoch 10/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0268 - acc: 0.9976 - val_loss: 0.0431 - val_acc: 0.9900
# Epoch 11/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0264 - acc: 0.9975 - val_loss: 0.0516 - val_acc: 0.9885
# Epoch 00011: early stopping
# test accuracy: 0.736228813559322

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(horizontal_flip=True, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 2s 18ms/step - loss: 0.3054 - acc: 0.8635 - val_loss: 0.1466 - val_acc: 0.9427
# Epoch 2/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.1266 - acc: 0.9584 - val_loss: 0.1070 - val_acc: 0.9670
# Epoch 3/50
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0997 - acc: 0.9689 - val_loss: 0.0777 - val_acc: 0.9799
# Epoch 4/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0802 - acc: 0.9772 - val_loss: 0.0779 - val_acc: 0.9785
# Epoch 5/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0648 - acc: 0.9847 - val_loss: 0.0680 - val_acc: 0.9771
# Epoch 6/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0537 - acc: 0.9885 - val_loss: 0.0620 - val_acc: 0.9857
# Epoch 7/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0452 - acc: 0.9909 - val_loss: 0.0583 - val_acc: 0.9871
# Epoch 8/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0380 - acc: 0.9938 - val_loss: 0.0625 - val_acc: 0.9857
# Epoch 9/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0396 - acc: 0.9924 - val_loss: 0.0534 - val_acc: 0.9900
# Epoch 10/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0317 - acc: 0.9957 - val_loss: 0.0525 - val_acc: 0.9871
# Epoch 11/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0296 - acc: 0.9968 - val_loss: 0.0618 - val_acc: 0.9871
# Epoch 12/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0283 - acc: 0.9973 - val_loss: 0.0724 - val_acc: 0.9857
# Epoch 13/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.0302 - acc: 0.9959 - val_loss: 0.0570 - val_acc: 0.9885
# Epoch 14/50
# 126/125 [==============================] - 2s 14ms/step - loss: 0.0246 - acc: 0.9986 - val_loss: 0.0544 - val_acc: 0.9885
# Epoch 00014: early stopping
# test accuracy: 0.6938559322033898

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(preprocessing_function=addNoise, data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.3276 - acc: 0.8508 - val_loss: 0.1232 - val_acc: 0.9556
# Epoch 2/50
# 126/125 [==============================] - 2s 13ms/step - loss: 0.1060 - acc: 0.9680 - val_loss: 0.0904 - val_acc: 0.9756
# Epoch 3/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0731 - acc: 0.9809 - val_loss: 0.0636 - val_acc: 0.9871
# Epoch 4/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0552 - acc: 0.9889 - val_loss: 0.0576 - val_acc: 0.9828
# Epoch 5/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0454 - acc: 0.9916 - val_loss: 0.0495 - val_acc: 0.9857
# Epoch 6/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0377 - acc: 0.9941 - val_loss: 0.0379 - val_acc: 0.9928
# Epoch 7/50
# 126/125 [==============================] - 2s 15ms/step - loss: 0.0331 - acc: 0.9952 - val_loss: 0.0485 - val_acc: 0.9857
# Epoch 8/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0306 - acc: 0.9960 - val_loss: 0.0395 - val_acc: 0.9914
# Epoch 9/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0254 - acc: 0.9987 - val_loss: 0.0310 - val_acc: 0.9928
# Epoch 10/50
# 126/125 [==============================] - 2s 17ms/step - loss: 0.0224 - acc: 0.9994 - val_loss: 0.0418 - val_acc: 0.9857
# Epoch 11/50
# 126/125 [==============================] - 2s 16ms/step - loss: 0.0235 - acc: 0.9984 - val_loss: 0.0363 - val_acc: 0.9928
# Epoch 00011: early stopping
# test accuracy: 0.6366525423728814

# %% [markdown]
# _How does CNN with data augmentation compare with your work in Tutorial 8?_
# - The performances of CNN outperform those of MLP.

# %% [markdown]
# # Test image
# Now lets try your face detector on a real image.  Download the "nasa-small.png" image and put it in the same directory as your ipynb file.  The below code will load the image, crop out image patches and then extract features. (this may take a few minutes)

# %%
fname = "nasa-small.png"

# %%
# load image
testimg3 = skimage.io.imread(fname)

# convert to grayscale
testimg = skimage.color.rgb2gray(testimg3)
print(testimg.shape)
plt.imshow(testimg, cmap='gray')
# Out:
# (210, 480)

# %%
# step size for the sliding window
step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg, (19,19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0]*psize[1], psize[2], psize[3], 1))
print(patches2.shape)

# histogram equalize patches (improves contrast)
#newI = empty(patches2.shape)
#for i in range(patches2.shape[0]):
#    newI[i,:,:] = skimage.exposure.equalize_hist(patches2[i,:,:])
newI = patches2
# Out:
# (5568, 19, 19, 1)

# %% [markdown]
# Now predict using your classifier.  The extracted images are in `newI`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

# initialize random seed
random.seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5), strides=(2,2), activation='relu', input_shape=(19,19,1), kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(40, (5,5), strides=(2,2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Conv2D(80, (5,5), strides=(1,1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001), padding='same'))
nn.add(Flatten())
nn.add(Dense(units=50, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0001)))
nn.add(Dense(units=2, activation='softmax', kernel_regularizer=keras.regularizers.l2(0.0001)))

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
            #callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)

plot_history(history)

prednewY = argmax(nn.predict(newI, verbose=False), axis=-1)
print("Prediction:", prednewY)

# prednewY = argmax(nn.predict(newI), axis=-1)
# Out:
# Epoch 1/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.4061 - acc: 0.8062 - val_loss: 0.1955 - val_acc: 0.9226
# Epoch 2/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.1916 - acc: 0.9306 - val_loss: 0.1193 - val_acc: 0.9556
# Epoch 3/50
# 126/125 [==============================] - 3s 26ms/step - loss: 0.1548 - acc: 0.9462 - val_loss: 0.1027 - val_acc: 0.9628
# Epoch 4/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.1265 - acc: 0.9592 - val_loss: 0.1502 - val_acc: 0.9542
# Epoch 5/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.1109 - acc: 0.9631 - val_loss: 0.0791 - val_acc: 0.9756
# Epoch 6/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.1042 - acc: 0.9681 - val_loss: 0.1353 - val_acc: 0.9513
# Epoch 7/50
# 126/125 [==============================] - 3s 23ms/step - loss: 0.0884 - acc: 0.9747 - val_loss: 0.0704 - val_acc: 0.9756
# Epoch 8/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0794 - acc: 0.9767 - val_loss: 0.0639 - val_acc: 0.9814
# Epoch 9/50
# 126/125 [==============================] - 2s 19ms/step - loss: 0.0772 - acc: 0.9771 - val_loss: 0.0497 - val_acc: 0.9885
# Epoch 10/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.0729 - acc: 0.9838 - val_loss: 0.0566 - val_acc: 0.9857
# Epoch 11/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0715 - acc: 0.9795 - val_loss: 0.0540 - val_acc: 0.9885
# Epoch 12/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0647 - acc: 0.9830 - val_loss: 0.0478 - val_acc: 0.9871
# Epoch 13/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0605 - acc: 0.9842 - val_loss: 0.0470 - val_acc: 0.9914
# Epoch 14/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.0557 - acc: 0.9866 - val_loss: 0.0460 - val_acc: 0.9857
# Epoch 15/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0625 - acc: 0.9831 - val_loss: 0.0409 - val_acc: 0.9914
# Epoch 16/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0569 - acc: 0.9850 - val_loss: 0.0393 - val_acc: 0.9928
# Epoch 17/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0517 - acc: 0.9882 - val_loss: 0.0386 - val_acc: 0.9928
# Epoch 18/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0510 - acc: 0.9893 - val_loss: 0.0339 - val_acc: 0.9971
# Epoch 19/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0488 - acc: 0.9909 - val_loss: 0.0292 - val_acc: 1.0000
# Epoch 20/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0437 - acc: 0.9911 - val_loss: 0.0320 - val_acc: 0.9957
# Epoch 21/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.0431 - acc: 0.9916 - val_loss: 0.0410 - val_acc: 0.9900
# Epoch 22/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0443 - acc: 0.9922 - val_loss: 0.0290 - val_acc: 0.9986
# Epoch 23/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.0425 - acc: 0.9909 - val_loss: 0.0307 - val_acc: 0.9971
# Epoch 24/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.0405 - acc: 0.9924 - val_loss: 0.0268 - val_acc: 0.9971
# Epoch 25/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0394 - acc: 0.9936 - val_loss: 0.0449 - val_acc: 0.9885
# Epoch 26/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0395 - acc: 0.9925 - val_loss: 0.0398 - val_acc: 0.9928
# Epoch 27/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0397 - acc: 0.9916 - val_loss: 0.0356 - val_acc: 0.9914
# Epoch 28/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0346 - acc: 0.9943 - val_loss: 0.0404 - val_acc: 0.9928
# Epoch 29/50
# 126/125 [==============================] - 2s 20ms/step - loss: 0.0356 - acc: 0.9939 - val_loss: 0.0317 - val_acc: 0.9943
# Epoch 30/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0369 - acc: 0.9941 - val_loss: 0.0404 - val_acc: 0.9885
# Epoch 31/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0362 - acc: 0.9939 - val_loss: 0.0294 - val_acc: 0.9971
# Epoch 32/50
# 126/125 [==============================] - 3s 20ms/step - loss: 0.0366 - acc: 0.9944 - val_loss: 0.0274 - val_acc: 0.9986
# Epoch 33/50
# 126/125 [==============================] - 3s 21ms/step - loss: 0.0339 - acc: 0.9955 - val_loss: 0.0395 - val_acc: 0.9900
# Epoch 34/50
# 126/125 [==============================] - 3s 22ms/step - loss: 0.0317 - acc: 0.9960 - val_loss: 0.0312 - val_acc: 0.9957
# Epoch 35/50
# 126/125 [==============================] - 4s 28ms/step - loss: 0.0343 - acc: 0.9943 - val_loss: 0.0345 - val_acc: 0.9928
# Epoch 36/50
# 126/125 [==============================] - 4s 29ms/step - loss: 0.0336 - acc: 0.9955 - val_loss: 0.0275 - val_acc: 0.9957
# Epoch 37/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.0363 - acc: 0.9941 - val_loss: 0.0284 - val_acc: 0.9986
# Epoch 38/50
# 126/125 [==============================] - 3s 26ms/step - loss: 0.0335 - acc: 0.9967 - val_loss: 0.0257 - val_acc: 0.9986
# Epoch 39/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.0345 - acc: 0.9949 - val_loss: 0.0249 - val_acc: 0.9986
# Epoch 40/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0309 - acc: 0.9965 - val_loss: 0.0315 - val_acc: 0.9928
# Epoch 41/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0296 - acc: 0.9967 - val_loss: 0.0522 - val_acc: 0.9871
# Epoch 42/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0277 - acc: 0.9978 - val_loss: 0.0308 - val_acc: 0.9943
# Epoch 43/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0268 - acc: 0.9982 - val_loss: 0.0320 - val_acc: 0.9957
# Epoch 44/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0302 - acc: 0.9967 - val_loss: 0.0349 - val_acc: 0.9928
# Epoch 45/50
# 126/125 [==============================] - 3s 27ms/step - loss: 0.0334 - acc: 0.9951 - val_loss: 0.0266 - val_acc: 0.9957
# Epoch 46/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0305 - acc: 0.9960 - val_loss: 0.0286 - val_acc: 0.9971
# Epoch 47/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0270 - acc: 0.9976 - val_loss: 0.0391 - val_acc: 0.9928
# Epoch 48/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0278 - acc: 0.9968 - val_loss: 0.0277 - val_acc: 0.9971
# Epoch 49/50
# 126/125 [==============================] - 3s 25ms/step - loss: 0.0280 - acc: 0.9973 - val_loss: 0.0302 - val_acc: 0.9957
# Epoch 50/50
# 126/125 [==============================] - 3s 24ms/step - loss: 0.0263 - acc: 0.9975 - val_loss: 0.0323 - val_acc: 0.9943
# Prediction: [0 0 0 ... 0 0 0]

# %% [markdown]
# Now we we will view the results on the image.  Use the below code. `prednewY` is the vector of predictions.

# %%
# reshape prediction to an image
imgY = prednewY.reshape(psize[0], psize[1])

# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0],9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg.shape[0]-imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0],testimg.shape[1]-imgY2.shape[1]))))
    
# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1-imgY2
tmp = nimgY2*testimg
detimg = dstack((imgY2+tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2,1,2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# (-0.5, 479.5, 209.5, -0.5)

# %% [markdown]
# _How did your face detector do compared to the last version?_
# - It performs very well compared with MLP model.

# %% [markdown]
# You can try it on your own images.  The faces should all be around 19x19 pixels though. We only used 1/8 of the training data. Try using more data to train it!
