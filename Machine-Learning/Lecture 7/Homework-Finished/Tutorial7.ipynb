# %% [markdown]
# **Name:** SHUYUE JIA
#
# **EID:** 56846018

# %% [markdown]
# # CS5489 - Tutorial 7
# ## Image Segmentation using Clustering
#
# In this tutorial you will use clustering algorithms to generate a segmentation of an image.  An image segmentation is a separation of an image into regions belonging to distinct objects.
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best) 
# jpg is better for images
IPython.core.display.set_matplotlib_formats("jpg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
import numpy as np
from sklearn import *
import glob
import os
import csv
import string
import skimage.io
import skimage.color
import skimage.util
random.seed(100)

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the data.  Download `imgdb.zip`, and unzip it in the same directory as this ipynb file.  Then run the following cell to load the image data.

# %%
filelist = glob.glob('imgdb/jpg/*.jpg')
gtpath   = 'imgdb/gtruth/'
if len(filelist) == 0:
    warn.error("Could not find imgdb directory!  " + 
               "Make sure you put it here: " + os.getcwd() )
else:
    imgdata = []
    gtdata  = []
    
    # load image data
    for f in filelist:
        # load image - byte [0 to 255]
        img = skimage.io.imread(f)
        
        (fdir1, fname)  = os.path.split(f)        

        # load GT segmentation (non-consecutive integers)
        gname = gtpath + fname[:-4] + "-gt.png"
        gtimg = skimage.io.imread(gname)
        
        # convert to consecutive integers
        cl = unique(gtimg)
        gtimg0 = gtimg.copy().astype(float64)
        for i in range(len(cl)):
            gtimg0[gtimg==cl[i]] = i
        
        imgdata.append(img)
        gtdata.append(gtimg0)
print(len(imgdata))
# Out:
# 14

# %% [markdown]
# There are 14 images.  Each image also has a ground-truth segmentation that was created by a human annotation.  Here is an example:

# %%
plt.subplot(1,2,1)
plt.imshow(imgdata[6], aspect='equal')
plt.title('image')
plt.subplot(1,2,2)
plt.imshow(gtdata[6], aspect='equal', cmap='jet')
plt.title('segmentation');

# %% [markdown]
# ## 2. Clustering with Color Features
# To segment an image, we will extract features from each pixel location.  Then, we cluster the extracted features into groups.  Pixel location that are clustered into the same group form a segment.
#
# For the features, we will use the "Lab" colorspace, rather than the RGB colors.  Also, we will ignore the "L" feature, which is brightness, resulting in a 2-dimensional color feature space (a, b). Here are a few helper functions: 1) extract Lab features along a regular grid on the image; 2) convert cluster labels into a segmentation image; 3) color a segmentation image using colors from the original image.

# %%
def getfeatures(img, segm=None, stepsize=7, use_loc = False):
    """
    getfeatures - extract features from an image
     [X, Y, L] = getfeatures(img, stepsize)
     INPUT
     img      - the image   [type = np.ndarray or Image]
     segm     - the gt segmentation (optional)
     stepsize - window stepsize
     OUTPUT
      X   - the features: each row is a feature vector  [type = np.ndarray]
      Y   - the GT segment labels for each feature (if segm is provided)
      L   - dictionary containing location information of each feature
    """
    winsize = 7 # ensure it is an odd number
    if stepsize > winsize:
        raise Exception('stepsize larger than window size')
    # convert to LAB
    yimg = skimage.color.rgb2lab(img)

    offset = floor((winsize-1)/2)
    sy,sx, sc = img.shape

    if use_loc:
        Xdim = 4
    else:
        Xdim = 2
    
    # extract window patches with stepsize
    patches = skimage.util.view_as_windows(yimg, (winsize, winsize, 3), step=stepsize)    
    psize = patches.shape
    
    # get coordinates of windows
    rangex = arange(psize[1])*stepsize + offset
    rangey = arange(psize[0])*stepsize + offset

    X = zeros((psize[0] * psize[1], Xdim));
    
    if segm is None:
        Y = None
    else:
        Y = zeros((X.shape[0],))
    
    i = 0
    for x in range(psize[1]):
        for y in range(psize[0]):
            myu = mean(patches[y,x,0,:,:,1].flatten())
            myv = mean(patches[y,x,0,:,:,2].flatten())
            myy = int(rangey[y])
            myx = int(rangex[x])
            
            if use_loc:
                X[i,:] = [myu, myv, myx, myy]
            else:
                X[i,:] = [myu, myv]
                
            if Y is not None:
                Y[i] = segm[myy, myx]
                
            i = i + 1 
    
    L = {'rangex':rangex, 'rangey':rangey, 'offset':offset, 'sx':sx, 'sy':sy, \
         'stepsize':stepsize, 'winsize':winsize}
    return X, Y, L

def labels2seg(Y,L):
    """
    labels2segm - form a segmentation image using cluster labels
    segm = labels2segm(Y, L)
    Y - cluster labels for each location
    L - location dictionary from getfeatures
    segm - output segmentation image
    """
    segm = zeros((L['sy'], L['sx']))
    # <= offset if floor((winsize-1)/2)>= floor(stepsize/2) 
    rstep = int(floor(L['stepsize']/2.0)) 
    stepbox = range(-rstep, L['stepsize'] - rstep)
    rx = asarray(L['rangex'], dtype=int) + int(L['offset'])
    ry = asarray(L['rangey'], dtype=int) + int(L['offset'])
    Y_reshaped = Y.reshape((ry.size, rx.size),order='F')
    for i in stepbox:
        for j in stepbox:
            segm[ix_(ry + j, rx + i)] = Y_reshaped
    ## Now fil in the borders if they are missing
    minx = min(rx) + stepbox[0] - 1
    maxx = max(rx) + stepbox[-1] + 1
    miny = min(ry) + stepbox[0] - 1
    maxy = max(ry) + stepbox[-1] + 1

    if 0 <= minx:
        ## fill in left edge
        segm[:, 0:minx+1] = segm[:,minx+1].reshape((-1,1))
    if maxx < L['sx']:
        ## fill in right edge
        segm[:,maxx:] = segm[:,maxx-1].reshape((-1,1))
    if 0 < miny:
        ## fill in top edge
        segm[0:miny+1,:] = segm[miny+1,:].reshape((1,-1))
    if maxy < L['sy']:
        ## fill in bottom edge
        segm[maxy:,:] = segm[maxy-1,:].reshape((1,-1))
    return segm    

def colorsegms(segm, img):
    """
    colorsegm - color a segmentation based on the image
    csegm = colorsegm(segm, img)
    segm = the segmentation image  [type = np.ndarray]
    img = the original image    [type = np.ndarray (or Image)]
    csegm = the colored segmentation -- each segment is colored based on the 
            average pixel color within the segment.
    """
    img = asarray(img).copy()
    if segm.shape[0:2] != img.shape[0:2]:
        raise Exception('The shape of segmentation and image are not consistent') 
    rimg, gimg, bimg = img[:,:,0], img[:,:,1], img[:,:,2]
    for i in range(0, int(max(segm.flatten())) + 1):
        # assume label starts from 1
        ind = (segm == i)
        rimg[ind] = mean(rimg[ind].flatten())
        gimg[ind] = mean(gimg[ind].flatten())
        bimg[ind] = mean(bimg[ind].flatten())
    # handle outliers from DBSCAN
    ind = (segm == -1)
    rimg[ind] = 0
    gimg[ind] = 0
    bimg[ind] = 0
    return img

# %% [markdown]
# Next, we use the `getfeatures` function to extract features from an image.  `X` contains the feature vectors. `L` contains information about where each features was extracted, which is used later generate the segmentation.

# %%
# image to use
img = imgdata[6]
gt  = gtdata[6]

# extract features, each row is a feature vector
Xo, Ytrue, L = getfeatures(img, gt)
print(Xo.shape)
print(Ytrue.shape)
print(len(L))

# normalize features
scaler = preprocessing.StandardScaler()  
X = scaler.fit_transform(Xo)

# view the image
plt.figure(figsize=(9,5))
plt.subplot(1,2,1)
plt.imshow(img, interpolation='nearest')
plt.title("image")

# view the features
plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c='b', s=5, edgecolor='none')
plt.ylabel('b'); 
plt.xlabel('a'); 
plt.grid(True)
# Out:
# (3060, 2)
# (3060,)
# 7

# %% [markdown]
# Here is the segmented image, with the segment labels shown as colors.  The goal is to recoever these labels using clustering.

# %%
# view the image
plt.figure(figsize=(9,5))

plt.subplot(1,2,1)
plt.imshow(gt, interpolation='nearest', cmap='jet')
plt.title("true segmentation")

# view the features
plt.subplot(1,2,2)
plt.scatter(X[:,0], X[:,1], c=Ytrue, s=5, edgecolor='none', cmap='jet')
plt.ylabel('b'); 
plt.xlabel('a'); 
plt.grid(True)

# %% [markdown]
# Now use a clustering algorithm to group the data into 5 clusters.

# %%
# K-Means with 5 clusters 
# (automatically does 10 random initializations) 
km = cluster.KMeans(n_clusters=5, random_state=4487) 
Y = km.fit_predict(X) # cluster data, and return labels

cc = km.cluster_centers_ 
cl = km.labels_

print(np.shape(cc))
print(np.shape(cl))
# Out:
# (5, 2)
# (3060,)

# %% [markdown]
# Once you have the cluster labels (Y), use the below code to generate the segmentation image and view it.  You can also view the scatter plot with `showscatter`.

# %%
def showsegm(segm, img):
    "show a segmentation"
    
    # fill segmentation with colors from the image
    csegm = colorsegms(segm, img)
    
    # view the images, segmentation, and ground-truth
    plt.figure(figsize=(12,5))
    plt.subplot(1,3,1)
    plt.imshow(img, interpolation='nearest')
    plt.title('image')
    plt.subplot(1,3,2)
    plt.imshow(segm, interpolation='nearest', cmap='jet')
    plt.title('segmentation')
    plt.subplot(1,3,3)
    plt.imshow(gt, interpolation='nearest', cmap='jet')
    plt.title("ground truth")
    
    return segm

def showscatter(X,Y):
    "show a scatter plot of clusters"
    
    if X.shape[1] == 2:
        plt.figure()
        plt.scatter(X[:,0], X[:,1], c=Y, s=5, edgecolor='none', cmap='jet')
        plt.grid(True)
        plt.xlabel('a')
        plt.ylabel('b')
    else:
        plt.figure(figsize=(12,3))

        plt.subplot(1,4,1)
        plt.scatter(X[:,0], X[:,1], c=Y, s=5, edgecolor='none', cmap='jet')
        plt.xlabel('a'); plt.ylabel('b'); plt.grid(True)

        plt.subplot(1,4,2)
        plt.scatter(X[:,2], X[:,3], c=Y, s=5, edgecolor='none', cmap='jet')
        plt.xlabel('x-pos'); plt.ylabel('y-pos'); plt.grid(True)

        plt.subplot(1,4,3)
        plt.scatter(X[:,2], X[:,0], c=Y, s=5, edgecolor='none', cmap='jet')
        plt.xlabel('x-pos'); plt.ylabel('a'); plt.grid(True)

        plt.subplot(1,4,4)
        plt.scatter(X[:,3], X[:,1], c=Y, s=5, edgecolor='none', cmap='jet')
        plt.xlabel('y-pos'); plt.ylabel('b'); plt.grid(True)
        
        plt.tight_layout()

# %%
# convert cluster labels to a segmentation image
segm = labels2seg(Y, L)

# show the segmentation
showsegm(segm, img)

# show the scatter plot
showscatter(X, Y)

# %% [markdown]
# Next we evaluate the segmentation with the ground-truth provided by a human annotator.  We cannot just check that the cluster assignments for each pixel are the same, since the cluster indices can be permuted.  We will use the _Adjusted Rand Index_, which calculates how often a pair of pixels is assigned correctly to the same cluster or not.  Use the below code to calculate the ARI. Higher values are better, and the maximum value is 1.

# %%
# calculate ARI
#ari = metrics.adjusted_rand_score(gt.flatten(), segm.flatten())
ari = metrics.adjusted_rand_score(Ytrue, Y)
print("ARI =",ari)
# Out:
# ARI = 0.4105924201620701

# %% [markdown]
# Try different clustering algorithms and settings (K, bandwidth, etc) to get the best segmentation as measured by ARI.

# %%
# K-Means Algorithm
for i in range(2, 10):
    # K-Means with 5 clusters 
    # (automatically does 10 random initializations) 
    km = cluster.KMeans(n_clusters=i, random_state=4487) 
    Y = km.fit_predict(X) # cluster data, and return labels
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print(i, "cluster, the ARI =", ari)
# Out:
# 2 cluster, the ARI = 0.46556058127303895
# 3 cluster, the ARI = 0.3419810063631298
# 4 cluster, the ARI = 0.5805084672467716
# 5 cluster, the ARI = 0.4105924201620701
# 6 cluster, the ARI = 0.3598825990384778
# 7 cluster, the ARI = 0.27412861445172443
# 8 cluster, the ARI = 0.3223201137929471
# 9 cluster, the ARI = 0.29836915159359895

# %%
# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print(i, "cluster, the ARI =", ari)

# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='full', random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('covariance_type=full :::', i, "cluster, the ARI =", ari)

# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='diag', random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('covariance_type=diag :::', i, "cluster, the ARI =", ari)

# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='spherical', random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('covariance_type=spherical :::', i, "cluster, the ARI =", ari)
# Out:
# 2 cluster, the ARI = 0.45048576484554237
# 3 cluster, the ARI = 0.5194419176003285
# 4 cluster, the ARI = 0.38429626486491303
# 5 cluster, the ARI = 0.350152739285423
# 6 cluster, the ARI = 0.221159361938838
# 7 cluster, the ARI = 0.3006637014230816
# 8 cluster, the ARI = 0.28829696362395896
# 9 cluster, the ARI = 0.2385238654808283
# covariance_type=full ::: 2 cluster, the ARI = 0.45048576484554237
# covariance_type=full ::: 3 cluster, the ARI = 0.5194419176003285
# covariance_type=full ::: 4 cluster, the ARI = 0.38429626486491303
# covariance_type=full ::: 5 cluster, the ARI = 0.350152739285423
# covariance_type=full ::: 6 cluster, the ARI = 0.221159361938838
# covariance_type=full ::: 7 cluster, the ARI = 0.3006637014230816
# covariance_type=full ::: 8 cluster, the ARI = 0.28829696362395896
# covariance_type=full ::: 9 cluster, the ARI = 0.2385238654808283
# covariance_type=diag ::: 2 cluster, the ARI = 0.3808379117298272
# covariance_type=diag ::: 3 cluster, the ARI = 0.35076291747817456
# covariance_type=diag ::: 4 cluster, the ARI = 0.5846197502901924
# covariance_type=diag ::: 5 cluster, the ARI = 0.3697705558778428
# covariance_type=diag ::: 6 cluster, the ARI = 0.31688904605626106
# covariance_type=diag ::: 7 cluster, the ARI = 0.27556255834639115
# covariance_type=diag ::: 8 cluster, the ARI = 0.317661956312406
# covariance_type=diag ::: 9 cluster, the ARI = 0.3029571685295394
# covariance_type=spherical ::: 2 cluster, the ARI = 0.41011733670824685
# covariance_type=spherical ::: 3 cluster, the ARI = 0.3502348581917368
# covariance_type=spherical ::: 4 cluster, the ARI = 0.5499381981711033
# covariance_type=spherical ::: 5 cluster, the ARI = 0.39236254230824763
# covariance_type=spherical ::: 6 cluster, the ARI = 0.3469400717065371
# covariance_type=spherical ::: 7 cluster, the ARI = 0.2721631872900118
# covariance_type=spherical ::: 8 cluster, the ARI = 0.31011073527526756
# covariance_type=spherical ::: 9 cluster, the ARI = 0.29133859656218747

# %%
# Dirichlet Process GMM

for i in range(2, 10):
    # fit a GMM 
    dpgmm = mixture.BayesianGaussianMixture(covariance_type='full', 
                                        weight_concentration_prior=1, 
                                        n_components=i, 
                                        max_iter=1000, 
                                        random_state=4487)    
    dpgmm.fit(X) 
    Y = dpgmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('Dirichlet Process GMM: ', i, "cluster, the ARI =", ari)
# Out:
# Dirichlet Process GMM:  2 cluster, the ARI = 0.45048576484554237
# Dirichlet Process GMM:  3 cluster, the ARI = 0.3512022303632137
# Dirichlet Process GMM:  4 cluster, the ARI = 0.38238302738567803
# Dirichlet Process GMM:  5 cluster, the ARI = 0.33399891672781434
# Dirichlet Process GMM:  6 cluster, the ARI = 0.21088028572306133
# Dirichlet Process GMM:  7 cluster, the ARI = 0.2481167427953898
# Dirichlet Process GMM:  8 cluster, the ARI = 0.21147081575531365
# Dirichlet Process GMM:  9 cluster, the ARI = 0.22203527382393623

# %%
# Mean-shift algorithm
for i in range(1, 10):
    # fit a Mean-shift algorithm 
    ms = cluster.MeanShift(bandwidth=i, bin_seeding=True, n_jobs=-1)
    Y = ms.fit_predict(X)
    
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('Mean-shift algorithm: ', i, "bandwidth, the ARI =", ari)
# Out:
# Mean-shift algorithm:  1 bandwidth, the ARI = 0.35118969430170116
# Mean-shift algorithm:  2 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  3 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  4 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  5 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  6 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  7 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  8 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  9 bandwidth, the ARI = 0.0

# %%
# Spectral Clustering
for i in range(1, 10):
    # fit a Spectral Clustering 
    sc = cluster.SpectralClustering(n_clusters=i, 
                                    affinity='rbf', 
                                    gamma=1.0, 
                                    assign_labels='discretize', 
                                    n_jobs=-1) 
    Y = sc.fit_predict(X)   
    
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('Spectral Clustering: ', i, "bandwidth, the ARI =", ari)
# Out:
# Spectral Clustering:  1 bandwidth, the ARI = 0.0
# Spectral Clustering:  2 bandwidth, the ARI = 0.4640617994396265
# Spectral Clustering:  3 bandwidth, the ARI = 0.34921494628850747
# Spectral Clustering:  4 bandwidth, the ARI = 0.5801851145730744
# Spectral Clustering:  5 bandwidth, the ARI = 0.5336463720353141
# Spectral Clustering:  6 bandwidth, the ARI = 0.3476301406181187
# Spectral Clustering:  7 bandwidth, the ARI = 0.2584943359131319
# Spectral Clustering:  8 bandwidth, the ARI = 0.2403112531626775
# Spectral Clustering:  9 bandwidth, the ARI = 0.2299227271858816

# %% [markdown]
# _Which algorithm performs the best?  Why?_
# - From the results, the GMM model with diagonal covariance type and Spectral Clustering performed best.
# The reason might be that the distribution of feature vectors could be better modeled based on the diagonal covariance matrix by e.g., elliptical cluster shapes. However, it may be sensitive to initialization and could get bad solutions due to local minimum. As for the Spectral Clustering, it can handle clusters of any shape, as long as connected. But it needs to choose K and cannot assign novel points to a cluster. Overall, if we choose other features, the performance might be totally different. I think it is still task-dependent.

# %% [markdown]
# ## 3. Color and Position Features
# You may notice that the segmentation is not spatially smooth -- that is, there are some "loner" pixels that are not the same cluster as the surrounding pixels.  This is because we are only clustering color.  One way to fix this is to include the (x,y) coordinate of the pixel as part of the feature vector.  This way, clusters will have pixels that are spatially close together.
#
# The below code extracts a 4-dimensional feature vector, where the first 2 features are the color channels and the last 2 features are the position.

# %%
# extract features with location
Xo, Ytrue,L = getfeatures(img, gt, use_loc=True)
print(Xo.shape)

# normalize features
scaler = preprocessing.StandardScaler()  
X = scaler.fit_transform(Xo)

# rescale position features
# larger values emphasize clustering by position more
X[:,2:4] *= 0.5
# Out:
# (3060, 4)

# %% [markdown]
# Here are plots of the 4 features.

# %%
showscatter(X, Ytrue)

# %% [markdown]
# Run clustering algorithms on the 4-dimensional data.  Try different algorithms and parameters to get the best ARI.

# %%
# K-Means Algorithm
for i in range(2, 10):
    # K-Means with 5 clusters 
    # (automatically does 10 random initializations) 
    km = cluster.KMeans(n_clusters=i, random_state=4487) 
    Y = km.fit_predict(X) # cluster data, and return labels
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print(i, "cluster, the ARI =", ari)
# Out:
# 2 cluster, the ARI = 0.46401517185339614
# 3 cluster, the ARI = 0.24372214116710594
# 4 cluster, the ARI = 0.633355010531123
# 5 cluster, the ARI = 0.4529019346741613
# 6 cluster, the ARI = 0.40364466941987254
# 7 cluster, the ARI = 0.3274423566735803
# 8 cluster, the ARI = 0.3240216058085024
# 9 cluster, the ARI = 0.29616393852684164

# %%
# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print(i, "cluster, the ARI =", ari)

# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='full', random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('covariance_type=full :::', i, "cluster, the ARI =", ari)

# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='diag', random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('covariance_type=diag :::', i, "cluster, the ARI =", ari)

# GMM Algorithm
for i in range(2, 10):
    # fit a GMM 
    gmm = mixture.GaussianMixture(n_components=i, covariance_type='spherical', random_state=4487, n_init=10)
    gmm.fit(X) 
    
    Y = gmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('covariance_type=spherical :::', i, "cluster, the ARI =", ari)
# Out:
# 2 cluster, the ARI = 0.4555095732170376
# 3 cluster, the ARI = 0.2520358382834804
# 4 cluster, the ARI = 0.675361450937292
# 5 cluster, the ARI = 0.6507466093785076
# 6 cluster, the ARI = 0.44335424238644655
# 7 cluster, the ARI = 0.3933270592058904
# 8 cluster, the ARI = 0.42738385264972295
# 9 cluster, the ARI = 0.36209163972452724
# covariance_type=full ::: 2 cluster, the ARI = 0.4555095732170376
# covariance_type=full ::: 3 cluster, the ARI = 0.2520358382834804
# covariance_type=full ::: 4 cluster, the ARI = 0.675361450937292
# covariance_type=full ::: 5 cluster, the ARI = 0.6507466093785076
# covariance_type=full ::: 6 cluster, the ARI = 0.44335424238644655
# covariance_type=full ::: 7 cluster, the ARI = 0.3933270592058904
# covariance_type=full ::: 8 cluster, the ARI = 0.42738385264972295
# covariance_type=full ::: 9 cluster, the ARI = 0.36209163972452724
# covariance_type=diag ::: 2 cluster, the ARI = 0.33731722493899813
# covariance_type=diag ::: 3 cluster, the ARI = 0.40042974114586
# covariance_type=diag ::: 4 cluster, the ARI = 0.4848225132558542
# covariance_type=diag ::: 5 cluster, the ARI = 0.4394949390810123
# covariance_type=diag ::: 6 cluster, the ARI = 0.2757406280204754
# covariance_type=diag ::: 7 cluster, the ARI = 0.3302774605644275
# covariance_type=diag ::: 8 cluster, the ARI = 0.365682959620701
# covariance_type=diag ::: 9 cluster, the ARI = 0.3281373403919965
# covariance_type=spherical ::: 2 cluster, the ARI = 0.4569526816184737
# covariance_type=spherical ::: 3 cluster, the ARI = 0.35294559855554053
# covariance_type=spherical ::: 4 cluster, the ARI = 0.6387794116969484
# covariance_type=spherical ::: 5 cluster, the ARI = 0.5936837636941427
# covariance_type=spherical ::: 6 cluster, the ARI = 0.4140962961977181
# covariance_type=spherical ::: 7 cluster, the ARI = 0.3222655370254377
# covariance_type=spherical ::: 8 cluster, the ARI = 0.330444099473536
# covariance_type=spherical ::: 9 cluster, the ARI = 0.29538372654406825

# %%
# Dirichlet Process GMM

for i in range(2, 10):
    # fit a GMM 
    dpgmm = mixture.BayesianGaussianMixture(covariance_type='full', 
                                        weight_concentration_prior=1, 
                                        n_components=i, 
                                        max_iter=1000, 
                                        random_state=4487)    
    dpgmm.fit(X) 
    Y = dpgmm.predict(X)
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('Dirichlet Process GMM: ', i, "cluster, the ARI =", ari)
# Out:
# Dirichlet Process GMM:  2 cluster, the ARI = 0.4555095732170376
# Dirichlet Process GMM:  3 cluster, the ARI = 0.2642215804133289
# Dirichlet Process GMM:  4 cluster, the ARI = 0.7209850800591139
# Dirichlet Process GMM:  5 cluster, the ARI = 0.5232226761510007
# Dirichlet Process GMM:  6 cluster, the ARI = 0.43269603879345003
# Dirichlet Process GMM:  7 cluster, the ARI = 0.4698580359256128
# Dirichlet Process GMM:  8 cluster, the ARI = 0.3057885381313384
# Dirichlet Process GMM:  9 cluster, the ARI = 0.3612010732698321

# %%
# Mean-shift algorithm
for i in range(1, 10):
    # fit a Mean-shift algorithm 
    ms = cluster.MeanShift(bandwidth=i, bin_seeding=True, n_jobs=-1)
    Y = ms.fit_predict(X)
    
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('Mean-shift algorithm: ', i, "bandwidth, the ARI =", ari)
# Out:
# Mean-shift algorithm:  1 bandwidth, the ARI = 0.2848310558995644
# Mean-shift algorithm:  2 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  3 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  4 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  5 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  6 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  7 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  8 bandwidth, the ARI = 0.0
# Mean-shift algorithm:  9 bandwidth, the ARI = 0.0

# %%
# Spectral Clustering
for i in range(1, 10):
    # fit a Spectral Clustering 
    sc = cluster.SpectralClustering(n_clusters=i, 
                                    affinity='rbf', 
                                    gamma=1.0, 
                                    assign_labels='discretize', 
                                    n_jobs=-1) 
    Y = sc.fit_predict(X)   
    
    ari = metrics.adjusted_rand_score(Ytrue, Y)
    print('Spectral Clustering: ', i, "bandwidth, the ARI =", ari)
# Out:
# Spectral Clustering:  1 bandwidth, the ARI = 0.0
# Spectral Clustering:  2 bandwidth, the ARI = 0.4744969062273473
# Spectral Clustering:  3 bandwidth, the ARI = 0.35861783252774115
# Spectral Clustering:  4 bandwidth, the ARI = 0.6299386232489285
# Spectral Clustering:  5 bandwidth, the ARI = 0.5845532732135486
# Spectral Clustering:  6 bandwidth, the ARI = 0.3907321537322469
# Spectral Clustering:  7 bandwidth, the ARI = 0.36858957433475426
# Spectral Clustering:  8 bandwidth, the ARI = 0.30280304863354673
# Spectral Clustering:  9 bandwidth, the ARI = 0.2888175260484835

# %% [markdown]
# _Which method performs the best?  Why?_
# - The results and reasons are the same as the above cell.

# %% [markdown]
# _Does including the position features improve the segmentation results?_
# - Yes! Adding new features may improve the results, to some extent.
