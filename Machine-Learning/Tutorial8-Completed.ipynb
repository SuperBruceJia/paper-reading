# %% [markdown]
# **Name:** \_\_\_\_\_
#
# **EID:** \_\_\_\_\_

# %% [markdown]
# # CS5489 - Tutorial 8
# ## Face Detection with MLPs
#
# In this tutorial you will train an MLP to detect whether there is a face in a small image patch.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import os
import zipfile
import fnmatch
random.seed(100)
import skimage.io
import skimage.color
import skimage.transform
from scipy import ndimage

# %% [markdown]
# Next we will load keras and tensorflow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import struct
K.set_image_data_format('channels_last')

# %%
print(keras.__version__, tf.__version__)
# Out:
# 2.4.0 2.4.1

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the images.  Download `faces.zip`, and place it in the same directory as this ipynb file.  **Do not unzip it.** Then run the following cell to load the images.

# %%
imgdata = {'train':[], 'test':[]}
classes = {'train':[], 'test':[]}

# the dataset is too big, so subsample the training and test sets...
# reduce training set by a factor of 4
train_subsample = 1
train_counter = [0, 0]
# maximum number of samples in each class for test set
test_maxsample = 472
test_counter = [0, 0]

# load the zip file
filename = 'faces.zip'
zfile = zipfile.ZipFile(filename, 'r')

for name in zfile.namelist():
    # check file name matches
    if fnmatch.fnmatch(name, "faces/*/*/*.png"):
        
        # filename is : faces/train/face/fname.png
        (fdir1, fname)  = os.path.split(name)     # get file name
        (fdir2, fclass) = os.path.split(fdir1) # get class (face, nonface)
        (fdir3, fset)   = os.path.split(fdir2) # get training/test set
        # class 1 = face; class 0 = non-face
        myclass = int(fclass == "face")  

        loadme = False
        if fset == 'train':
            if (train_counter[myclass] % train_subsample) == 0:
                loadme = True
            train_counter[myclass] += 1
        elif fset == 'test':
            if test_counter[myclass] < test_maxsample:
                loadme = True
            test_counter[myclass] += 1
            
        if (loadme):
            # open file in memory, and parse as an image
            myfile = zfile.open(name)
            #img = matplotlib.image.imread(myfile)
            img = skimage.io.imread(myfile)
            # convert to grayscale
            img = skimage.color.rgb2gray(img)
            myfile.close()
            
            # append data
            imgdata[fset].append(img)
            classes[fset].append(myclass)

        
zfile.close()
imgsize = img.shape

print(len(imgdata['train']))
print(len(imgdata['test']))
trainclass2start = sum(classes['train'])
# Out:
# <ipython-input-4-b3235342933c>:43: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img = skimage.color.rgb2gray(img)
# 6977
# 944

# %% [markdown]
# Next we will convert the list of images into a block (array) of images for easier processing.

# %%
# convert list to numpy array
trainY = asarray(classes['train'])
testY  = asarray(classes['test'])

# convert class labels to binary indicators
trainYb = keras.utils.to_categorical(trainY)
testYb  = keras.utils.to_categorical(testY)

# convert list of ndarray to ndarray
trainI = asarray(imgdata['train']).reshape((6977,19,19,1))
testI  = asarray(imgdata['test']).reshape((944,19,19,1))

# cleanup memory
del imgdata

# shuffle the data (since it is in order by class)
random.seed(123)
inds1 = random.permutation(len(trainI)).tolist()
inds2 = random.permutation(len(testI)).tolist()
trainYb = trainYb[inds1]
testYb  = testYb[inds2]
trainY = trainY[inds1]
testY  = testY[inds2]
trainI = trainI[inds1]
testI = testI[inds2]

print(trainI.shape)
print(testI.shape)
# Out:
# (6977, 19, 19, 1)
# (944, 19, 19, 1)

# %% [markdown]
# Each image is a 19x19x1 array of pixel values.  The last dimension is the number of channels in the image - in this case the image is grayscale, so there is only 1 channel.  Run the below code to show an example:

# %%
print(img.shape)
plt.subplot(1,2,1)
plt.imshow(squeeze(trainI[1]), cmap='gray', interpolation='nearest')
plt.title("face sample")
plt.subplot(1,2,2)
plt.imshow(squeeze(trainI[2]), cmap='gray', interpolation='nearest')
plt.title("non-face sample")
plt.show()
# Out:
# (19, 19)

# %% [markdown]
# Run the below code to show more images!

# %%
# function to make an image montage
def image_montage(X, imsize=None, maxw=10):
    """X can be a list of images, or a matrix of vectorized images.
      Specify imsize when X is a matrix."""
    tmp = []
    numimgs = len(X)
    
    # create a list of images (reshape if necessary)
    for i in range(0,numimgs):
        if imsize != None:
            tmp.append(X[i].reshape(imsize))
        else:
            tmp.append(squeeze(X[i]))
    
    # add blanks
    if (numimgs > maxw) and (mod(numimgs, maxw) > 0):
        leftover = maxw - mod(numimgs, maxw)
        meanimg = 0.5*(X[0].max()+X[0].min())
        for i in range(0,leftover):
            tmp.append(ones(tmp[0].shape)*meanimg)
    
    # make the montage
    tmp2 = []
    for i in range(0,len(tmp),maxw):
        tmp2.append( hstack(tmp[i:i+maxw]) )
    montimg = vstack(tmp2) 
    return montimg

# show images in a plot
def show_imgs(W_list, nc=10, highlight_green=None, highlight_red=None, titles=None):
    # nc is the number of columns
    nfilter = len(W_list)
    nr = (nfilter - 1) // nc + 1
    for i in range(nr):
        for j in range(nc):
            idx = i * nc + j
            if idx == nfilter:
                break
            plt.subplot(nr, nc, idx + 1)
            cur_W = W_list[idx]
            plt.imshow(cur_W,cmap='gray', interpolation='nearest')  
            if titles is not None:
                if isinstance(titles, str):
                    plt.title(titles.format(idx))
                else:
                    plt.title(titles[idx])
            
            if ((highlight_green is not None) and highlight_green[idx]) or \
               ((highlight_red is not None) and highlight_red[idx]): 
                ax = plt.gca()
                if highlight_green[idx]:
                    mycol = '#00FF00'
                else:
                    mycol = 'r'
                for S in ['bottom', 'top', 'right', 'left']:
                    ax.spines[S].set_color(mycol)
                    ax.spines[S].set_lw(2.0)
                ax.xaxis.set_ticks_position('none')               
                ax.yaxis.set_ticks_position('none')
                ax.set_xticks([])
                ax.set_yticks([])
            else:
                plt.gca().set_axis_off()

# show a few images
plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,0]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,1]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

# %% [markdown]
# Next we will generate the training/validation set from the training data.

# %%
# generate fixed validation set of 10% of the training set
vtrainI, validI, vtrainYb, validYb = \
  model_selection.train_test_split(trainI, trainYb, 
  train_size=0.9, test_size=0.1, random_state=4488)

# make validation data
validsetI = (validI, validYb)

print(vtrainI.shape)
print(validI.shape)
# Out:
# (6279, 19, 19, 1)
# (698, 19, 19, 1)

# %% [markdown]
# Here are some useful functions.

# %%
# compatible with v1 or v2
def tf_compat():
    if tf.__version__[0] == '1':
        return (tf.set_random_seed, 'acc')
    else:
        return (tf.random.set_seed, 'accuracy')
    
tf_set_seed, accname = tf_compat()

def plot_history(history): 
    fig, ax1 = plt.subplots()
    
    ax1.plot(history.history['loss'], 'r', label="training loss ({:.6f})".format(history.history['loss'][-1]))
    ax1.plot(history.history['val_loss'], 'r--', label="validation loss ({:.6f})".format(history.history['val_loss'][-1]))
    ax1.grid(True)
    ax1.set_xlabel('iteration')
    ax1.legend(loc="best", fontsize=9)    
    ax1.set_ylabel('loss', color='r')
    ax1.tick_params('y', colors='r')

    
    if accname in history.history:
        ax2 = ax1.twinx()

        ax2.plot(history.history[accname], 'b', label="training acc ({:.4f})".format(history.history[accname][-1]))
        ax2.plot(history.history['val_' + accname], 'b--', label="validation acc ({:.4f})".format(history.history['val_' + accname][-1]))

        ax2.legend(loc="best", fontsize=9)
        ax2.set_ylabel('acc', color='b')        
        ax2.tick_params('y', colors='b')

# %% [markdown]
# Now let's try a simple logistic regression classifier, trained using Keras. Since the inputs are images, we will convert the input image into a vector using the "Flatten" layer first.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,      # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00016: early stopping
# test accuracy: 0.6228813559322034

# %% [markdown]
# ## 2. Detection using MLP
#
# Train an MLP to classify an image patch as face or not face.  Use  `vtrainI` and `vtrainY` as the training set and `validsetI` as the validation set.  You can try different architectures, and adjust values of the learning rates, number of iterations, early stopping to get a good result.  Use a large batch size (e.g., 50) to speed up the training time.  Remember to add the `callbacks` so that you can monitor the training process.

# %%
### INSERT YOUR CODE HERE

# %%
# MLP: 200 - 2

K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=200, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00019: early stopping
# test accuracy: 0.6186440677966102

# %%
# MLP: 1000 -> 2
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=1000, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00016: early stopping
# test accuracy: 0.6419491525423728

# %%
# MLP: 2000 -> 2
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2000, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00017: early stopping
# test accuracy: 0.6430084745762712

# %%
# MLP: 500-100 -> 2

K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=500, activation='relu'))
nn.add(Dense(units=100, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00014: early stopping
# test accuracy: 0.6377118644067796

# %%
# MLP: 2000 -> 100  -> 2
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2000, activation='relu'))
nn.add(Dense(units=100, activation='relu'))
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00012: early stopping
# test accuracy: 0.5646186440677966

# %% [markdown]
# _How does the MLP compare to the linear and non-linear classifiers that you tried in Tutorial 4?_
# - **INSERT YOUR ANSWER HERE**
# - It's worse: 0.64 accuracy for MLP, compared to random forest with image features (0.814 accuracy).

# %% [markdown]
# ## 3. Data Augmentation
#
# The reason why we are not getting good accuracy with MLP is because there is not a lot of data, only ~7000 training images, compared to the number of parameters in the MLP.
#
# Augmenting the training data with permutations  (e.g., scaling, rotating, skewing, flipping) is a good way to create more "data" for training the network.
# This can prevent the MLP from overfitting, and improve its generalization.  We will use the built-in `ImageDataGenerator` to apply geometric transformations.

# %% [markdown]
# We can also add per-pixel noise or transformations. We define a few functions for adding per-pixel noise.  The following functions will add Gaussian pixel noise, add corruption noise (setting some input pixels to 0), scale and shift pixel values (changing contrast and brightness).

# %%
def add_gauss_noise(X, sigma2=0.05):
    # add Gaussian noise with zero mean, and variance sigma2
    return X + random.normal(0, sigma2, X.shape)

def add_corrupt_noise(X, p=0.1):
    # apply pixel corruption (zero out value) with probability p
    return X * random.binomial(1, 1-p, X.shape)

def add_scale_shift(X, sigma2=0.1, alpha2=0.2):
    # randomly scale and shift the pixel values (same for each image)
    # Xnew = a X + b
    # a is sampled from a Gaussian with mean 1, and variance sigma2
    # b is sampled from a Gaussian with mean 0, and variance alpha2
    if X.ndim == 3:
        dshape = (X.shape[0],1,1)
    elif X.ndim == 4:
        dshape = (X.shape[0],1,1,1)
    else:
        dshape = (1,)
    a = random.normal(1,sigma2, dshape)
    b = random.normal(0,alpha2, dshape)
    return minimum(maximum( a*X + b, 0.0), 1.0)

# %% [markdown]
# Next, we define a function for adding per-pixel noise (in this case just Gaussian noise). The noise is included using the `preprocessing_function` input of the `ImageDataGenerator`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

# %% [markdown]
# Next we can show some examples of augmented images. Run the code below to see different random augmentations.

# %%
img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

# %% [markdown]
# The augmented images look similar to the original image, but contain small differences that the network can use to learn more about the class.

# %% [markdown]
# Now let's try training logistic regression with data augmentation. Instead of `fit`, we now  use the `fit_generator` method, which will pass each input through the ImageDataGenerator before sending it to the MLP.  We disable early stopping so that the network sees more noisy data.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.01, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1599 - accuracy: 0.9409 - val_loss: 0.1172 - val_accuracy: 0.9484
# Epoch 32/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1524 - accuracy: 0.9365 - val_loss: 0.1172 - val_accuracy: 0.9499
# Epoch 33/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1609 - accuracy: 0.9367 - val_loss: 0.1252 - val_accuracy: 0.9427
# Epoch 34/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1593 - accuracy: 0.9377 - val_loss: 0.1266 - val_accuracy: 0.9398
# Epoch 35/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1516 - accuracy: 0.9398 - val_loss: 0.0978 - val_accuracy: 0.9642
# Epoch 36/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1633 - accuracy: 0.9355 - val_loss: 0.1180 - val_accuracy: 0.9470
# Epoch 37/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1470 - accuracy: 0.9435 - val_loss: 0.1140 - val_accuracy: 0.9499
# Epoch 38/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1448 - accuracy: 0.9407 - val_loss: 0.0993 - val_accuracy: 0.9613
# Epoch 39/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1437 - accuracy: 0.9444 - val_loss: 0.1119 - val_accuracy: 0.9542
# Epoch 40/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1499 - accuracy: 0.9399 - val_loss: 0.1131 - val_accuracy: 0.9513
# Epoch 41/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1536 - accuracy: 0.9402 - val_loss: 0.1210 - val_accuracy: 0.9456
# Epoch 42/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1548 - accuracy: 0.9440 - val_loss: 0.1023 - val_accuracy: 0.9542
# Epoch 43/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1510 - accuracy: 0.9379 - val_loss: 0.1098 - val_accuracy: 0.9513
# Epoch 44/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1405 - accuracy: 0.9425 - val_loss: 0.1037 - val_accuracy: 0.9585
# Epoch 45/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1534 - accuracy: 0.9387 - val_loss: 0.1208 - val_accuracy: 0.9427
# Epoch 46/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1474 - accuracy: 0.9386 - val_loss: 0.1187 - val_accuracy: 0.9484
# Epoch 47/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1542 - accuracy: 0.9395 - val_loss: 0.0996 - val_accuracy: 0.9613
# Epoch 48/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1389 - accuracy: 0.9484 - val_loss: 0.1200 - val_accuracy: 0.9456
# Epoch 49/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1508 - accuracy: 0.9370 - val_loss: 0.0937 - val_accuracy: 0.9628
# Epoch 50/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1366 - accuracy: 0.9495 - val_loss: 0.1139 - val_accuracy: 0.9499

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.6970338983050848

# %% [markdown]
# Using data augmentation, the test accuracy improves from 0.622 to 0.697!

# %% [markdown]
# Now train your best MLP from the previous section using data augmentation.
# Try different per-pixel noise levels, and different options of the ImageDataGenerator (see [here](https://keras.io/preprocessing/image/)),
# and combinations of them.  Hopefully you should be able to improve the accuracy!

# %%
### INSERT YOUR CODE HERE ###

# %%
# define function to train the same network
def trainNN(dg):
    K.clear_session()
    random.seed(4487); tf_set_seed(4487)

    # build the network for logistic regression
    nn = Sequential()
    nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
    nn.add(Dense(units=2000, activation='relu'))
    nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

    # early stopping criteria
    earlystop = keras.callbacks.EarlyStopping(
                   monitor='val_' + accname,             # use validation accuracy for stopping
                   min_delta=0.0001, patience=5, 
                   verbose=1, mode='auto')
    callbacks_list = [earlystop]

    # compile and fit the network
    nn.compile(loss=keras.losses.categorical_crossentropy,
               optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
               metrics=['accuracy']  # also calculate accuracy during training
              )

    # fit with data generator
    history = nn.fit_generator(
                dg.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
                steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
                epochs=50,
#                callbacks=callbacks_list, 
                validation_data=validsetI, verbose=True)
    
    return nn

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0
50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0666 - accuracy: 0.9771 - val_loss: 0.0311 - val_accuracy: 0.9871
# Epoch 46/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0796 - accuracy: 0.9690 - val_loss: 0.0506 - val_accuracy: 0.9771
# Epoch 47/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0757 - accuracy: 0.9717 - val_loss: 0.0346 - val_accuracy: 0.9842
# Epoch 48/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0743 - accuracy: 0.9723 - val_loss: 0.0350 - val_accuracy: 0.9857
# Epoch 49/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.0647 - accuracy: 0.9756 - val_loss: 0.0778 - val_accuracy: 0.9642
# Epoch 50/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0666 - accuracy: 0.9757 - val_loss: 0.0333 - val_accuracy: 0.9842

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.8252118644067796

# %%
# also add scale_shift noise

# build the noise function
def addNoise(X):
    return add_scale_shift(add_gauss_noise(X, 0.04))

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 19ms/step - loss: 0.5294 - accuracy: 0.7774 - val_loss: 0.2130 - val_accuracy: 0.9069
# Epoch 2/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2857 - accuracy: 0.8818 - val_loss: 0.1598 - val_accuracy: 0.9312
# Epoch 3/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2611 - accuracy: 0.8911 - val_loss: 0.2356 - val_accuracy: 0.8940
# Epoch 4/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2453 - accuracy: 0.8997 - val_loss: 0.1107 - val_accuracy: 0.9513
# Epoch 5/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2406 - accuracy: 0.8984 - val_loss: 0.1592 - val_accuracy: 0.9241
# Epoch 6/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2234 - accuracy: 0.9066 - val_loss: 0.1581 - val_accuracy: 0.9370
# Epoch 7/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2126 - accuracy: 0.9128 - val_loss: 0.1524 - val_accuracy: 0.9384
# Epoch 8/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2033 - accuracy: 0.9222 - val_loss: 0.1064 - val_accuracy: 0.9542
# Epoch 9/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1996 - accuracy: 0.9125 - val_loss: 0.2704 - val_accuracy: 0.8840
# Epoch 10/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2039 - accuracy: 0.9159 - val_loss: 0.1173 - val_accuracy: 0.9542
# Epoch 11/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1897 - accuracy: 0.9229 - val_loss: 0.0981 - val_accuracy: 0.9628
# Epoch 12/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2062 - accuracy: 0.9155 - val_loss: 0.1169 - val_accuracy: 0.9542
# Epoch 13/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1849 - accuracy: 0.9207 - val_loss: 0.1084 - val_accuracy: 0.9570
# Epoch 14/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1800 - accuracy: 0.9302 - val_loss: 0.1300 - val_accuracy: 0.9456
# Epoch 15/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1780 - accuracy: 0.9253 - val_loss: 0.1068 - val_accuracy: 0.9570
# Epoch 16/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1840 - accuracy: 0.9249 - val_loss: 0.1422 - val_accuracy: 0.9456
# Epoch 17/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1803 - accuracy: 0.9277 - val_loss: 0.0736 - val_accuracy: 0.9728
# Epoch 18/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1688 - accuracy: 0.9326 - val_loss: 0.0888 - val_accuracy: 0.9613
# Epoch 19/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1768 - accuracy: 0.9265 - val_loss: 0.0866 - val_accuracy: 0.9628
# Epoch 20/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1740 - accuracy: 0.9240 - val_loss: 0.0882 - val_accuracy: 0.9685
# Epoch 21/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1718 - accuracy: 0.9273 - val_loss: 0.0865 - val_accuracy: 0.9628
# Epoch 22/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1613 - accuracy: 0.9379 - val_loss: 0.1010 - val_accuracy: 0.9613
# Epoch 23/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1442 - accuracy: 0.9420 - val_loss: 0.1124 - val_accuracy: 0.9570
# Epoch 24/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1561 - accuracy: 0.9420 - val_loss: 0.0834 - val_accuracy: 0.9642
# Epoch 25/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1538 - accuracy: 0.9378 - val_loss: 0.1101 - val_accuracy: 0.9527
# Epoch 26/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1535 - accuracy: 0.9405 - val_loss: 0.0890 - val_accuracy: 0.9628
# Epoch 27/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1481 - accuracy: 0.9405 - val_loss: 0.1505 - val_accuracy: 0.9370
# Epoch 28/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1625 - accuracy: 0.9369 - val_loss: 0.0825 - val_accuracy: 0.9628
# Epoch 29/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1471 - accuracy: 0.9429 - val_loss: 0.0701 - val_accuracy: 0.9685
# Epoch 30/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1494 - accuracy: 0.9399 - val_loss: 0.1221 - val_accuracy: 0.9484
# Epoch 31/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1554 - accuracy: 0.9428 - val_loss: 0.1714 - val_accuracy: 0.9312
# Epoch 32/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1307 - accuracy: 0.9485 - val_loss: 0.0943 - val_accuracy: 0.9570
# Epoch 33/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1564 - accuracy: 0.9398 - val_loss: 0.0785 - val_accuracy: 0.9656
# Epoch 34/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1448 - accuracy: 0.9394 - val_loss: 0.1013 - val_accuracy: 0.9613
# Epoch 35/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1449 - accuracy: 0.9438 - val_loss: 0.1065 - val_accuracy: 0.9570
# Epoch 36/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1466 - accuracy: 0.9407 - val_loss: 0.0642 - val_accuracy: 0.9799
# Epoch 37/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1479 - accuracy: 0.9453 - val_loss: 0.0691 - val_accuracy: 0.9699
# Epoch 38/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1506 - accuracy: 0.9404 - val_loss: 0.0773 - val_accuracy: 0.9713
# Epoch 39/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1471 - accuracy: 0.9456 - val_loss: 0.0712 - val_accuracy: 0.9713
# Epoch 40/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1273 - accuracy: 0.9496 - val_loss: 0.1076 - val_accuracy: 0.9585
# Epoch 41/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1326 - accuracy: 0.9479 - val_loss: 0.0908 - val_accuracy: 0.9613
# Epoch 42/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1318 - accuracy: 0.9510 - val_loss: 0.0823 - val_accuracy: 0.9656
# Epoch 43/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1442 - accuracy: 0.9422 - val_loss: 0.0904 - val_accuracy: 0.9670
# Epoch 44/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1342 - accuracy: 0.9495 - val_loss: 0.0943 - val_accuracy: 0.9628
# Epoch 45/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1318 - accuracy: 0.9515 - val_loss: 0.1023 - val_accuracy: 0.9585
# Epoch 46/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1338 - accuracy: 0.9453 - val_loss: 0.1289 - val_accuracy: 0.9513
# Epoch 47/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1346 - accuracy: 0.9517 - val_loss: 0.0860 - val_accuracy: 0.9728
# Epoch 48/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1239 - accuracy: 0.9559 - val_loss: 0.0579 - val_accuracy: 0.9771
# Epoch 49/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1285 - accuracy: 0.9522 - val_loss: 0.0797 - val_accuracy: 0.9599
# Epoch 50/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1232 - accuracy: 0.9548 - val_loss: 0.1234 - val_accuracy: 0.9470

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.8326271186440678

# %%
# increase range of shifting, shear, zoom
# BEST

# build the noise function
def addNoise(X):
    return add_corrupt_noise(add_gauss_noise(X, 0.04))

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 20ms/step - loss: 0.4653 - accuracy: 0.8008 - val_loss: 0.1806 - val_accuracy: 0.9241
# Epoch 2/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2118 - accuracy: 0.9105 - val_loss: 0.2456 - val_accuracy: 0.9040
# Epoch 3/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2085 - accuracy: 0.9186 - val_loss: 0.1436 - val_accuracy: 0.9398
# Epoch 4/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.
50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1110 - accuracy: 0.9596 - val_loss: 0.0742 - val_accuracy: 0.9699
# Epoch 36/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1093 - accuracy: 0.9582 - val_loss: 0.0720 - val_accuracy: 0.9642
# Epoch 37/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0997 - accuracy: 0.9647 - val_loss: 0.0658 - val_accuracy: 0.9699
# Epoch 38/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0985 - accuracy: 0.9636 - val_loss: 0.0495 - val_accuracy: 0.9785
# Epoch 39/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1038 - accuracy: 0.9600 - val_loss: 0.0845 - val_accuracy: 0.9713
# Epoch 40/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1083 - accuracy: 0.9566 - val_loss: 0.0589 - val_accuracy: 0.9742
# Epoch 41/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0912 - accuracy: 0.9657 - val_loss: 0.0744 - val_accuracy: 0.9685
# Epoch 42/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1047 - accuracy: 0.9612 - val_loss: 0.0564 - val_accuracy: 0.9814
# Epoch 43/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1085 - accuracy: 0.9571 - val_loss: 0.0480 - val_accuracy: 0.9828
# Epoch 44/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1006 - accuracy: 0.9623 - val_loss: 0.0830 - val_accuracy: 0.9599
# Epoch 45/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1040 - accuracy: 0.9599 - val_loss: 0.0384 - val_accuracy: 0.9842
# Epoch 46/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0996 - accuracy: 0.9619 - val_loss: 0.0583 - val_accuracy: 0.9742
# Epoch 47/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1031 - accuracy: 0.9631 - val_loss: 0.0582 - val_accuracy: 0.9785
# Epoch 48/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1023 - accuracy: 0.9579 - val_loss: 0.0543 - val_accuracy: 0.9771
# Epoch 49/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0969 - accuracy: 0.9627 - val_loss: 0.1088 - val_accuracy: 0.9556
# Epoch 50/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0969 - accuracy: 0.9618 - val_loss: 0.0591 - val_accuracy: 0.9814

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.847457627118644

# %%
# increase range of shifting, shear, zoom

# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.1)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 20ms/step - loss: 0.5811 - accuracy: 0.8048 - val_loss: 0.1339 - val_accuracy: 0.9398
# Epoch 2/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2102 - accuracy: 0.9123 - val_loss: 0.1251 - val_accuracy: 0.9499
# Epoch 3/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1879 - accuracy: 0.9243 - val_loss: 0.1118 - val_accuracy: 0.9513
# Epoch 4/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1639 - accuracy: 0.9379 - val_loss: 0.1269 - val_accuracy: 0.9456
# Epoch 5/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1631 - accuracy: 0.9378 - val_loss: 0.0977 - val_accuracy: 0.9628
# Epoch 6/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1505 - accuracy: 0.9392 - val_loss: 0.1150 - val_accuracy: 0.9499
# Epoch 7/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1573 - accuracy: 0.9359 - val_loss: 0.0828 - val_accuracy: 0.9699
# Epoch 8/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1424 - accuracy: 0.9460 - val_loss: 0.0857 - val_accuracy: 0.9613
# Epoch 9/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1391 - accuracy: 0.9488 - val_loss: 0.1172 - val_accuracy: 0.9570
# Epoch 10/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1382 - accuracy: 0.9489 - val_loss: 0.1050 - val_accuracy: 0.9527
# Epoch 11/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1298 - accuracy: 0.9521 - val_loss: 0.0842 - val_accuracy: 0.9656
# Epoch 12/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1401 - accuracy: 0.9440 - val_loss: 0.0730 - val_accuracy: 0.9670
# Epoch 13/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1144 - accuracy: 0.9565 - val_loss: 0.0750 - val_accuracy: 0.9699
# Epoch 14/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1129 - accuracy: 0.9604 - val_loss: 0.0945 - val_accuracy: 0.9728
# Epoch 15/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1346 - accuracy: 0.9522 - val_loss: 0.0977 - val_accuracy: 0.9585
# Epoch 16/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1171 - accuracy: 0.9536 - val_loss: 0.0493 - val_accuracy: 0.9785
# Epoch 17/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1081 - accuracy: 0.9521 - val_loss: 0.0806 - val_accuracy: 0.9685
# Epoch 18/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1178 - accuracy: 0.9542 - val_loss: 0.0644 - val_accuracy: 0.9742
# Epoch 19/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1038 - accuracy: 0.9636 - val_loss: 0.0976 - val_accuracy: 0.9642
# Epoch 20/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1119 - accuracy: 0.9590 - val_loss: 0.0565 - val_accuracy: 0.9785
# Epoch 21/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1186 - accuracy: 0.9550 - val_loss: 0.0626 - val_accuracy: 0.9771
# Epoch 22/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1046 - accuracy: 0.9574 - val_loss: 0.0639 - val_accuracy: 0.9799
# Epoch 23/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0948 - accuracy: 0.9653 - val_loss: 0.0800 - val_accuracy: 0.9713
# Epoch 24/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0984 - accuracy: 0.9613 - val_loss: 0.0701 - val_accuracy: 0.9771
# Epoch 25/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1005 - accuracy: 0.9623 - val_loss: 0.0732 - val_accuracy: 0.9699
# Epoch 26/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1131 - accuracy: 0.9573 - val_loss: 0.0533 - val_accuracy: 0.9771
# Epoch 27/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0993 - accuracy: 0.9608 - val_loss: 0.0657 - val_accuracy: 0.9742
# Epoch 28/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0906 - accuracy: 0.9640 - val_loss: 0.0810 - val_accuracy: 0.9628
# Epoch 29/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0858 - accuracy: 0.9675 - val_loss: 0.0575 - val_accuracy: 0.9828
# Epoch 30/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0833 - accuracy: 0.9678 - val_loss: 0.0694 - val_accuracy: 0.9728
# Epoch 31/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1036 - accuracy: 0.9628 - val_loss: 0.0573 - val_accuracy: 0.9756
# Epoch 32/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0996 - accuracy: 0.9630 - val_loss: 0.1074 - val_accuracy: 0.9570
# Epoch 33/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0861 - accuracy: 0.9675 - val_loss: 0.0859 - val_accuracy: 0.9613
# Epoch 34/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0934 - accuracy: 0.9670 - val_loss: 0.0549 - val_accuracy: 0.9771
# Epoch 35/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0983 - accuracy: 0.9643 - val_loss: 0.0517 - val_accuracy: 0.9814
# Epoch 36/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0878 - accuracy: 0.9647 - val_loss: 0.0661 - val_accuracy: 0.9728
# Epoch 37/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0912 - accuracy: 0.9663 - val_loss: 0.0646 - val_accuracy: 0.9742
# Epoch 38/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0956 - accuracy: 0.9613 - val_loss: 0.0491 - val_accuracy: 0.9828
# Epoch 39/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0821 - accuracy: 0.9704 - val_loss: 0.0686 - val_accuracy: 0.9742
# Epoch 40/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0948 - accuracy: 0.9624 - val_loss: 0.0418 - val_accuracy: 0.9842
# Epoch 41/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0877 - accuracy: 0.9695 - val_loss: 0.0794 - val_accuracy: 0.9685
# Epoch 42/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0890 - accuracy: 0.9649 - val_loss: 0.0869 - val_accuracy: 0.9613
# Epoch 43/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1011 - accuracy: 0.9623 - val_loss: 0.0647 - val_accuracy: 0.9728
# Epoch 44/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0784 - accuracy: 0.9729 - val_loss: 0.0552 - val_accuracy: 0.9742
# Epoch 45/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0815 - accuracy: 0.9697 - val_loss: 0.0757 - val_accuracy: 0.9699
# Epoch 46/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0773 - accuracy: 0.9701 - val_loss: 0.0613 - val_accuracy: 0.9814
# Epoch 47/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1005 - accuracy: 0.9588 - val_loss: 0.0554 - val_accuracy: 0.9742
# Epoch 48/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0690 - accuracy: 0.9746 - val_loss: 0.0497 - val_accuracy: 0.9785
# Epoch 49/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0768 - accuracy: 0.9685 - val_loss: 0.0650 - val_accuracy: 0.9742
# Epoch 50/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0733 - accuracy: 0.9733 - val_loss: 0.0414 - val_accuracy: 0.9842

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.8421610169491526

# %% [markdown]
# _Which type of augmentation improves the accuracy the most?  Why?  How does NN with data augmentation compare with your work in Tutorial 4?_
# - **INSERT YOUR ANSWER HERE**

# %% [markdown]
# - **INSERT YOUR ANSWER HERE**
# - transformations, gaussian noise, scale+shift
# - make the NN invariant to all these transformations
# - Now accuracy is 0.84, which is better than Tutorial 4

# %% [markdown]
# # Test image
# Now lets try your face detector on a real image.  Download the "nasa-small.png" image and put it in the same directory as your ipynb file.  The below code will load the image, crop out image patches and then extract features. (this may take a few minutes)

# %%
fname = "nasa-small.png"

# %%
# load image
testimg3 = skimage.io.imread(fname)

# convert to grayscale
testimg = skimage.color.rgb2gray(testimg3)
print(testimg.shape)
plt.imshow(testimg, cmap='gray')
# Out:
# (210, 480)
# <ipython-input-35-1ceedb6e5bb3>:5: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   testimg = skimage.color.rgb2gray(testimg3)

# %%
# step size for the sliding window
step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg, (19,19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0]*psize[1], psize[2], psize[3], 1))
print(patches2.shape)

# histogram equalize patches (improves contrast)
#newI = empty(patches2.shape)
#for i in range(patches2.shape[0]):
#    newI[i,:,:] = skimage.exposure.equalize_hist(patches2[i,:,:])
newI = patches2
# Out:
# (5568, 19, 19, 1)

# %% [markdown]
# Now predict using your classifier.  The extracted images are in `newI`.

# %%
### YOUR CODE HERE
prednewY = argmax(nn.predict(newI, verbose=False), axis=-1)

# %% [markdown]
# Now we we will view the results on the image.  Use the below code. `prednewY` is the vector of predictions.

# %%
# reshape prediction to an image
imgY = prednewY.reshape(psize[0], psize[1])

# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0],9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg.shape[0]-imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0],testimg.shape[1]-imgY2.shape[1]))))
    
# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1-imgY2
tmp = nimgY2*testimg
detimg = dstack((imgY2+tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2,1,2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# (-0.5, 479.5, 209.5, -0.5)

# %% [markdown]
# _How did your face detector do compared to the last version?_
# - **INSERT YOUR ANSWER HERE**

# %% [markdown]
# - **INSERT YOUR ANSWER HERE**
# -  less FP than before

# %% [markdown]
# You can try it on your own images.  The faces should all be around 19x19 pixels though.
# We only used 1/8 of the training data. Try using more data to train it!
