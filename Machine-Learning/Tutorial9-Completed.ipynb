# %% [markdown]
# **Name:** \_\_\_\_\_
#
# **EID:** \_\_\_\_\_

# %% [markdown]
# # CS5489 - Tutorial 9
# ## Face Detection with CNNs
#
# In the previous tutorial, you used an MLP to detect a face in a small image patch.
# In this tutorial you will train a CNN instead of an MLP.
#
# First we need to initialize Python.  Run the below cell.

# %%
# %matplotlib inline
import IPython.core.display         
# setup output image format (Chrome works best)
IPython.core.display.set_matplotlib_formats("svg")
import matplotlib.pyplot as plt
import matplotlib
from numpy import *
from sklearn import *
import os
import zipfile
import fnmatch
random.seed(100)
import skimage.io
import skimage.color
import skimage.transform
from scipy import ndimage

# %% [markdown]
# Next we will load keras and tensorflow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import backend as K
import struct
K.set_image_data_format('channels_last')
print(keras.__version__, tf.__version__)
# Out:
# 2.4.0 2.4.1

# %% [markdown]
# ## 1. Loading Data and Pre-processing
# Next we need to load the images.  Download `faces.zip`, and place it in the same directory as this ipynb file.  **Do not unzip it.** Then run the following cell to load the images.

# %%
imgdata = {'train':[], 'test':[]}
classes = {'train':[], 'test':[]}

# the dataset is too big, so subsample the training and test sets...
# reduce training set by a factor of 4
train_subsample = 1
train_counter = [0, 0]
# maximum number of samples in each class for test set
test_maxsample = 472
test_counter = [0, 0]

# load the zip file
filename = 'faces.zip'
zfile = zipfile.ZipFile(filename, 'r')

for name in zfile.namelist():
    # check file name matches
    if fnmatch.fnmatch(name, "faces/*/*/*.png"):
        
        # filename is : faces/train/face/fname.png
        (fdir1, fname)  = os.path.split(name)     # get file name
        (fdir2, fclass) = os.path.split(fdir1) # get class (face, nonface)
        (fdir3, fset)   = os.path.split(fdir2) # get training/test set
        # class 1 = face; class 0 = non-face
        myclass = int(fclass == "face")  

        loadme = False
        if fset == 'train':
            if (train_counter[myclass] % train_subsample) == 0:
                loadme = True
            train_counter[myclass] += 1
        elif fset == 'test':
            if test_counter[myclass] < test_maxsample:
                loadme = True
            test_counter[myclass] += 1
            
        if (loadme):
            # open file in memory, and parse as an image
            myfile = zfile.open(name)
            #img = matplotlib.image.imread(myfile)
            img = skimage.io.imread(myfile)
            # convert to grayscale
            img = skimage.color.rgb2gray(img)
            myfile.close()
            
            # append data
            imgdata[fset].append(img)
            classes[fset].append(myclass)

        
zfile.close()
imgsize = img.shape

print(len(imgdata['train']))
print(len(imgdata['test']))
trainclass2start = sum(classes['train'])
# Out:
# <ipython-input-3-b3235342933c>:43: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img = skimage.color.rgb2gray(img)
# 6977
# 944

# %% [markdown]
# Next we will convert the list of images into a block (array) of images for easier processing.

# %%
# convert list to numpy array
trainY = asarray(classes['train'])
testY  = asarray(classes['test'])

# convert class labels to binary indicators
trainYb = keras.utils.to_categorical(trainY)
testYb  = keras.utils.to_categorical(testY)

# convert list of ndarray to ndarray
trainI = asarray(imgdata['train']).reshape((6977,19,19,1))
testI  = asarray(imgdata['test']).reshape((944,19,19,1))

# cleanup memory
del imgdata

# shuffle the data (since it is in order by class)
random.seed(123)
inds1 = random.permutation(len(trainI)).tolist()
inds2 = random.permutation(len(testI)).tolist()
trainYb = trainYb[inds1]
testYb  = testYb[inds2]
trainY = trainY[inds1]
testY  = testY[inds2]
trainI = trainI[inds1]
testI = testI[inds2]

print(trainI.shape)
print(testI.shape)
# Out:
# (6977, 19, 19, 1)
# (944, 19, 19, 1)

# %% [markdown]
# Each image is a 19x19x1 array of pixel values.  The last dimension is the number of channels in the image - in this case the image is grayscale, so there is only 1 channel.  Run the below code to show an example:

# %%
print(img.shape)
plt.subplot(1,2,1)
plt.imshow(squeeze(trainI[1]), cmap='gray', interpolation='nearest')
plt.title("face sample")
plt.subplot(1,2,2)
plt.imshow(squeeze(trainI[2]), cmap='gray', interpolation='nearest')
plt.title("non-face sample")
plt.show()
# Out:
# (19, 19)

# %% [markdown]
# Run the below code to show more images!

# %%
# function to make an image montage
def image_montage(X, imsize=None, maxw=10):
    """X can be a list of images, or a matrix of vectorized images.
      Specify imsize when X is a matrix."""
    tmp = []
    numimgs = len(X)
    
    # create a list of images (reshape if necessary)
    for i in range(0,numimgs):
        if imsize != None:
            tmp.append(X[i].reshape(imsize))
        else:
            tmp.append(squeeze(X[i]))
    
    # add blanks
    if (numimgs > maxw) and (mod(numimgs, maxw) > 0):
        leftover = maxw - mod(numimgs, maxw)
        meanimg = 0.5*(X[0].max()+X[0].min())
        for i in range(0,leftover):
            tmp.append(ones(tmp[0].shape)*meanimg)
    
    # make the montage
    tmp2 = []
    for i in range(0,len(tmp),maxw):
        tmp2.append( hstack(tmp[i:i+maxw]) )
    montimg = vstack(tmp2) 
    return montimg

# show images in a plot
def show_imgs(W_list, nc=10, highlight_green=None, highlight_red=None, titles=None):
    # nc is the number of columns
    nfilter = len(W_list)
    nr = (nfilter - 1) // nc + 1
    for i in range(nr):
        for j in range(nc):
            idx = i * nc + j
            if idx == nfilter:
                break
            plt.subplot(nr, nc, idx + 1)
            cur_W = W_list[idx]
            plt.imshow(cur_W,cmap='gray', interpolation='nearest')  
            if titles is not None:
                if isinstance(titles, str):
                    plt.title(titles.format(idx))
                else:
                    plt.title(titles[idx])
            
            if ((highlight_green is not None) and highlight_green[idx]) or \
               ((highlight_red is not None) and highlight_red[idx]): 
                ax = plt.gca()
                if highlight_green[idx]:
                    mycol = '#00FF00'
                else:
                    mycol = 'r'
                for S in ['bottom', 'top', 'right', 'left']:
                    ax.spines[S].set_color(mycol)
                    ax.spines[S].set_lw(2.0)
                ax.xaxis.set_ticks_position('none')               
                ax.yaxis.set_ticks_position('none')
                ax.set_xticks([])
                ax.set_yticks([])
            else:
                plt.gca().set_axis_off()

# show a few images
plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,0]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

plt.figure(figsize=(9,4))
plt.imshow(image_montage(trainI[trainYb[:,1]==1][0:50]), cmap='gray', interpolation='nearest')
plt.show()

# %% [markdown]
# Next we will generate the training/validation set from the training data.

# %%
# generate fixed validation set of 10% of the training set
vtrainI, validI, vtrainYb, validYb = \
  model_selection.train_test_split(trainI, trainYb, 
  train_size=0.9, test_size=0.1, random_state=4488)

# make validation data
validsetI = (validI, validYb)

print(vtrainI.shape)
print(validI.shape)
# Out:
# (6279, 19, 19, 1)
# (698, 19, 19, 1)

# %% [markdown]
# Here are some useful functions.

# %%
# compatible with v1 or v2
def tf_compat():
    if tf.__version__[0] == '1':
        return (tf.set_random_seed, 'acc')
    else:
        return (tf.random.set_seed, 'accuracy')
    
tf_set_seed, accname = tf_compat()

def plot_history(history): 
    fig, ax1 = plt.subplots()
    
    ax1.plot(history.history['loss'], 'r', label="training loss ({:.6f})".format(history.history['loss'][-1]))
    ax1.plot(history.history['val_loss'], 'r--', label="validation loss ({:.6f})".format(history.history['val_loss'][-1]))
    ax1.grid(True)
    ax1.set_xlabel('iteration')
    ax1.legend(loc="best", fontsize=9)    
    ax1.set_ylabel('loss', color='r')
    ax1.tick_params('y', colors='r')

    if accname in history.history:
        ax2 = ax1.twinx()

        ax2.plot(history.history[accname], 'b', label="training acc ({:.4f})".format(history.history[accname][-1]))
        ax2.plot(history.history['val_'+accname], 'b--', label="validation acc ({:.4f})".format(history.history['val_'+accname][-1]))

        ax2.legend(loc="best", fontsize=9)
        ax2.set_ylabel('acc', color='b')        
        ax2.tick_params('y', colors='b')

# %% [markdown]
# Now let's try a simple logistic regression classifier, trained using Keras. Since the inputs are images, we will convert the input image into a vector using the "Flatten" layer first.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI,  # specify the validation set
                 verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00016: early stopping
# test accuracy: 0.6228813559322034

# %% [markdown]
# ## 2. Detection using CNN
#
# Train an CNN to classify an image patch as face or not face.  Use  `vtrainI` and `vtrainY` as the training set and `validsetI` as the validation set.  You can try different architectures, and adjust values of the learning rates, number of iterations, early stopping, regularization, etc. to get a good result.  Use a large batch size (e.g., 50) to speed up the training time.  Remember to add the `callbacks` so that you can monitor the training process.

# %%
### INSERT YOUR CODE HERE

# %%
# conv(20,5x5) - Dropout - 50 - Dropout - 2
K.clear_session()

# initialize random seed
random.seed(4487); tf_set_seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(20, (5,5),        # channel, kerne size
              strides=(1,1),    # stride
              activation='relu',
              padding='same',   # convolution padding
              input_shape=(19,19,1),
              kernel_regularizer=keras.regularizers.l2(0.0001)
       ))
nn.add(Flatten())   # flatten the feature map into a vector to apply Dense layers
nn.add(Dropout(rate=0.5))
nn.add(Dense(units=50, activation='relu', 
      ))
nn.add(Dropout(rate=0.5))
nn.add(Dense(units=2, activation='softmax', 
            ))

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.02, momentum=0.9, nesterov=True), 
          metrics=['accuracy'])
history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI, verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00016: early stopping
# test accuracy: 0.6716101694915254

# %%
# conv(10,5x5) - Dropout - conv(20,3x3) - Dropout - 100 - 2
K.clear_session()

# initialize random seed
random.seed(4487); tf_set_seed(4487)

# build the network
nn = Sequential()
nn.add(Conv2D(10, (5,5),        # channel, kerne size
              strides=(2,2),    # stride
              activation='relu',
              padding='same',  
              input_shape=(19,19,1),
       ))
nn.add(Dropout(rate=0.5))
nn.add(Conv2D(20, (3,3),        # channel, kerne size
              strides=(1,1),    # stride
              kernel_regularizer=keras.regularizers.l2(0.0001),
              activation='relu', padding='same',
       ))

nn.add(Flatten())   # flatten the feature map into a vector to apply Dense layers
nn.add(Dropout(rate=0.5))
nn.add(Dense(units=100, activation='relu', 
              kernel_regularizer=keras.regularizers.l2(0.0001)
      ))
nn.add(Dense(units=2, activation='softmax',               
             kernel_regularizer=keras.regularizers.l2(0.0001)))
       
# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.02, momentum=0.9, nesterov=True), 
          metrics=['accuracy'])
history = nn.fit(vtrainI, vtrainYb, epochs=100, batch_size=50, 
                 callbacks=callbacks_list, 
                 validation_data=validsetI, verbose=False)

plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# Epoch 00020: early stopping
# test accuracy: 0.7341101694915254

# %% [markdown]
# _How does the MLP compare to the linear and non-linear classifiers that you tried in Tutorial 4?_
# - **INSERT YOUR ANSWER HERE**

# %% [markdown]
# - **INSERT YOUR ANSWER HERE**
# - It's still much worse: 0.734 for CNN, compared to RF of 0.814 accuracy.

# %% [markdown]
# ## 3. Data Augmentation
#
# Now use data augmentation (introduced in the last tutorial) to try to improve the accuracy.

# %% [markdown]
# We can also add per-pixel noise or transformations. We define a few functions for adding per-pixel noise.  The following functions will add Gaussian pixel noise, add corruption noise (setting some input pixels to 0), scale and shift pixel values (changing contrast and brightness).

# %%
def add_gauss_noise(X, sigma2=0.05):
    # add Gaussian noise with zero mean, and variance sigma2
    return X + random.normal(0, sigma2, X.shape)

def add_corrupt_noise(X, p=0.1):
    # apply pixel corruption (zero out value) with probability p
    return X * random.binomial(1, 1-p, X.shape)

def add_scale_shift(X, sigma2=0.1, alpha2=0.2):
    # randomly scale and shift the pixel values (same for each image)
    # Xnew = a X + b
    # a is sampled from a Gaussian with mean 1, and variance sigma2
    # b is sampled from a Gaussian with mean 0, and variance alpha2
    if X.ndim == 3:
        dshape = (X.shape[0],1,1)
    elif X.ndim == 4:
        dshape = (X.shape[0],1,1,1)
    else:
        dshape = (1,)
    a = random.normal(1,sigma2, dshape)
    b = random.normal(0,alpha2, dshape)
    return minimum(maximum( a*X + b, 0.0), 1.0)

# %% [markdown]
# Next, we define a function for adding per-pixel noise (in this case just Gaussian noise). The noise is included using the `preprocessing_function` input of the `ImageDataGenerator`.

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

# %% [markdown]
# Next we can show some examples of augmented images. Run the code below to see different random augmentations.

# %%
img = trainI[4]
imgs = [img[:,:,0]]

cnt = 0
for augimg, augy in datagen.flow(img.reshape(1,19,19,1), [1], batch_size=1):
    imgs.append(augimg[0,:,:,0])
    cnt += 1
    if cnt > 4:
        # we need to break the loop by hand because
        # the generator loops indefinitely
        break

titles = ['original image', 'augmented', 'augmented', 'augmented', 'augmented', 'augmented']
plt.figure(figsize=(8,6))
show_imgs(imgs, nc=3, titles=titles)

# %% [markdown]
# The augmented images look similar to the original image, but contain small differences that the network can use to learn more about the class.

# %% [markdown]
# Now let's try training logistic regression with data augmentation. Instead of "fit", we now  use the "fit_generator" method, which will pass each input through the ImageDataGenerator before sending it to the MLP.  We also disable early stopping so that the training sees more augmented data.

# %%
# initialize random seed
K.clear_session()
random.seed(4487); tf_set_seed(4487)

# build the network for logistic regression
nn = Sequential()
nn.add(Flatten(input_shape=(19,19,1)))        # vectorize the input image
nn.add(Dense(units=2, activation='softmax'))  # classification layer (2 classes)

# early stopping criteria
earlystop = keras.callbacks.EarlyStopping(
               monitor='val_'+accname,             # use validation accuracy for stopping
               min_delta=0.0001, patience=5, 
               verbose=1, mode='auto')
callbacks_list = [earlystop]

# compile and fit the network
nn.compile(loss=keras.losses.categorical_crossentropy,
           optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.9, nesterov=True), 
           metrics=['accuracy']  # also calculate accuracy during training
          )

# fit with data generator
history = nn.fit_generator(
            datagen.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
            steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
            epochs=50,
#           callbacks=callbacks_list, 
            validation_data=validsetI, verbose=True)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3622 - accuracy: 0.8465 - val_loss: 0.1926 - val_accuracy: 0.9212
# Epoch 2/50
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1763 - accuracy: 0.9253 - val_loss: 0.1410 - val_accuracy: 0.9384
# Epoch 3/50
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1687 - accuracy: 0.9314 - val_loss: 0.1469 - val_accuracy: 0.9398
# Epoch 4/50
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1744 - accuracy: 0.9334 - val_loss: 0.1345 - val_accuracy: 0.9427
# Epoch 5/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1517 - accuracy: 0.9410 - val_loss: 0.0873 - val_accuracy: 0.9656
# Epoch 6/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1684 - accuracy: 0.9324 - val_loss: 0.0933 - val_accuracy: 0.9628
# Epoch 7/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1640 - accuracy: 0.9363 - val_loss: 0.0891 - val_accuracy: 0.9656
# Epoch 8/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1506 - accuracy: 0.9376 - val_loss: 0.1662 - val_accuracy: 0.9269
# Epoch 9/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1638 - accuracy: 0.9292 - val_loss: 0.0996 - val_accuracy: 0.9599
# Epoch 10/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1585 - accuracy: 0.9379 - val_loss: 0.0929 - val_accuracy: 0.9642
# Epoch 11/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1731 - accuracy: 0.9300 - val_loss: 0.1047 - val_accuracy: 0.9456
# Epoch 12/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1696 - accuracy: 0.9314 - val_loss: 0.1048 - val_accuracy: 0.9556
# Epoch 13/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1640 - accuracy: 0.9318 - val_loss: 0.1204 - val_accuracy: 0.9470
# Epoch 14/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1513 - accuracy: 0.9405 - val_loss: 0.0918 - val_accuracy: 0.9613
# Epoch 15/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1592 - accuracy: 0.9359 - val_loss: 0.1004 - val_accuracy: 0.9628
# Epoch 16/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1604 - accuracy: 0.9359 - val_loss: 0.1668 - val_accuracy: 0.9284
# Epoch 17/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1682 - accuracy: 0.9372 - val_loss: 0.1088 - val_accuracy: 0.9585
# Epoch 18/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1707 - accuracy: 0.9333 - val_loss: 0.0929 - val_accuracy: 0.9642
# Epoch 19/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1630 - accuracy: 0.9372 - val_loss: 0.1759 - val_accuracy: 0.9255
# Epoch 20/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1779 - accuracy: 0.9291 - val_loss: 0.1407 - val_accuracy: 0.9341
# Epoch 21/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1475 - accuracy: 0.9447 - val_loss: 0.1045 - val_accuracy: 0.9556
# Epoch 22/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1616 - accuracy: 0.9349 - val_loss: 0.1221 - val_accuracy: 0.9456
# Epoch 23/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1601 - accuracy: 0.9397 - val_loss: 0.1015 - val_accuracy: 0.9527
# Epoch 24/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1689 - accuracy: 0.9342 - val_loss: 0.1176 - val_accuracy: 0.9413
# Epoch 25/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1466 - accuracy: 0.9432 - val_loss: 0.1028 - val_accuracy: 0.9527
# Epoch 26/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1535 - accuracy: 0.9445 - val_loss: 0.1215 - val_accuracy: 0.9470
# Epoch 27/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1683 - accuracy: 0.9325 - val_loss: 0.1315 - val_accuracy: 0.9413
# Epoch 28/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1662 - accuracy: 0.9377 - val_loss: 0.1004 - val_accuracy: 0.9585
# Epoch 29/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1525 - accuracy: 0.9371 - val_loss: 0.0939 - val_accuracy: 0.9585
# Epoch 30/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1528 - accuracy: 0.9402 - val_loss: 0.0992 - val_accuracy: 0.9556
# Epoch 31/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1624 - accuracy: 0.9393 - val_loss: 0.1050 - val_accuracy: 0.9513
# Epoch 32/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1667 - accuracy: 0.9311 - val_loss: 0.0920 - val_accuracy: 0.9570
# Epoch 33/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1715 - accuracy: 0.9346 - val_loss: 0.0974 - val_accuracy: 0.9628
# Epoch 34/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1600 - accuracy: 0.9372 - val_loss: 0.0919 - val_accuracy: 0.9599
# Epoch 35/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1559 - accuracy: 0.9381 - val_loss: 0.0973 - val_accuracy: 0.9613
# Epoch 36/50
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1547 - accuracy: 0.9356 - val_loss: 0.1194 - val_accuracy: 0.9456
# Epoch 37/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1617 - accuracy: 0.9368 - val_loss: 0.1064 - val_accuracy: 0.9613
# Epoch 38/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1688 - accuracy: 0.9364 - val_loss: 0.1486 - val_accuracy: 0.9384
# Epoch 39/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1554 - accuracy: 0.9375 - val_loss: 0.1064 - val_accuracy: 0.9570
# Epoch 40/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1860 - accuracy: 0.9244 - val_loss: 0.2383 - val_accuracy: 0.9126
# Epoch 41/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1775 - accuracy: 0.9318 - val_loss: 0.0991 - val_accuracy: 0.9599
# Epoch 42/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1565 - accuracy: 0.9360 - val_loss: 0.1291 - val_accuracy: 0.9413
# Epoch 43/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1437 - accuracy: 0.9419 - val_loss: 0.1017 - val_accuracy: 0.9556
# Epoch 44/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1641 - accuracy: 0.9370 - val_loss: 0.1316 - val_accuracy: 0.9413
# Epoch 45/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1580 - accuracy: 0.9420 - val_loss: 0.1037 - val_accuracy: 0.9628
# Epoch 46/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1583 - accuracy: 0.9360 - val_loss: 0.0983 - val_accuracy: 0.9585
# Epoch 47/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1628 - accuracy: 0.9382 - val_loss: 0.1264 - val_accuracy: 0.9456
# Epoch 48/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1542 - accuracy: 0.9400 - val_loss: 0.1388 - val_accuracy: 0.9341
# Epoch 49/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1503 - accuracy: 0.9421 - val_loss: 0.1777 - val_accuracy: 0.9255
# Epoch 50/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1579 - accuracy: 0.9383 - val_loss: 0.0930 - val_accuracy: 0.9628

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.6917372881355932

# %% [markdown]
# Using data augmentation, the test accuracy improves from 0.622 to 0.692!

# %% [markdown]
# Now train your best CNN from the previous section using data augmentation.
# Try different per-pixel noise levels, and different options of the ImageDataGenerator (see [here](https://keras.io/preprocessing/image/)),
# and combinations of them.  Hopefully you should be able to improve the accuracy!

# %%
### INSERT YOUR CODE HERE ###

# %%
# define function to train the same network
def trainNN(dg):
    K.clear_session()
    random.seed(4487); tf_set_seed(4487)

    # build the network
    nn = Sequential()
    nn.add(Conv2D(10, (5,5),        # channel, kerne size
                  strides=(2,2),    # stride
                  activation='relu',
                  padding='same',  
                  input_shape=(19,19,1),
           ))
    nn.add(Dropout(rate=0.5))
    nn.add(Conv2D(20, (3,3),        # channel, kerne size
                  strides=(1,1),    # stride
                  kernel_regularizer=keras.regularizers.l2(0.0001),
                  activation='relu', padding='same',
           ))

    nn.add(Flatten())   # flatten the feature map into a vector to apply Dense layers
    nn.add(Dropout(rate=0.5))
    nn.add(Dense(units=100, activation='relu', 
                  kernel_regularizer=keras.regularizers.l2(0.0001)
          ))
    nn.add(Dense(units=2, activation='softmax',               
                 kernel_regularizer=keras.regularizers.l2(0.0001)))

    # compile and fit the network
    nn.compile(loss=keras.losses.categorical_crossentropy,
               optimizer=keras.optimizers.SGD(lr=0.02, momentum=0.9, nesterov=True), 
              metrics=['accuracy'])

    # fit with data generator
    history = nn.fit_generator(
                dg.flow(vtrainI, vtrainYb, batch_size=50),  # data from generator
                steps_per_epoch=len(vtrainI)/50,    # should be number of batches per epoch
                epochs=50,
                validation_data=validsetI, verbose=True)    
    return nn

# %%
# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.05,     # image shifting
    height_shift_range=0.05,    # image shifting
    shear_range=0.05,           # shear transformation
    zoom_range=0.05,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.5247 - accuracy: 0.7274 - val_loss: 0.2389 - val_accuracy: 0.9112
# Epoch 2/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2866 - accuracy: 0.8878 - val_loss: 0.2065 - val_accuracy: 0.9255
# Epoch 3/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.2437 - accuracy: 0.9080 - val_loss: 0.1494 - val_accuracy: 0.9542
# Epoch 4/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.2123 - accuracy: 0.9206 - val_loss: 0.1594 - val_accuracy: 0.9413
# Epoch 5/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1946 - accuracy: 0.9268 - val_loss: 0.1470 - val_accuracy: 0.9527
# Epoch 6/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1920 - accuracy: 0.9315 - val_loss: 0.1308 - val_accuracy: 0.9613
# Epoch 7/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1867 - accuracy: 0.9357 - val_loss: 0.1390 - val_accuracy: 0.9628
# Epoch 8/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1856 - accuracy: 0.9327 - val_loss: 0.1126 - val_accuracy: 0.9670
# Epoch 9/50
# 125/125 [==============================] - 4s 33ms/step - loss: 0.1684 - accuracy: 0.9436 - val_loss: 0.1085 - val_accuracy: 0.9685
# Epoch 10/50
# 125/125 [==============================] - 3s 20ms/step - loss: 0.1725 - accuracy: 0.9389 - val_loss: 0.1035 - val_accuracy: 0.9670
# Epoch 11/50
# 125/125 [==============================] - 2s 20ms/step - loss: 0.1591 - accuracy: 0.9453 - val_loss: 0.1139 - val_accuracy: 0.9656
# Epoch 12/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1442 - accuracy: 0.9526 - val_loss: 0.0960 - val_accuracy: 0.9699
# Epoch 13/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1373 - accuracy: 0.9552 - val_loss: 0.1203 - val_accuracy: 0.9599
# Epoch 14/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.1359 - accuracy: 0.9551 - val_loss: 0.0887 - val_accuracy: 0.9756
# Epoch 15/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1378 - accuracy: 0.9548 - val_loss: 0.0726 - val_accuracy: 0.9828
# Epoch 16/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1407 - accuracy: 0.9506 - val_loss: 0.0815 - val_accuracy: 0.9756
# Epoch 17/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1405 - accuracy: 0.9548 - val_loss: 0.0942 - val_accuracy: 0.9685
# Epoch 18/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1362 - accuracy: 0.9561 - val_loss: 0.0943 - val_accuracy: 0.9728
# Epoch 19/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.1244 - accuracy: 0.9630 - val_loss: 0.0741 - val_accuracy: 0.9799
# Epoch 20/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.1240 - accuracy: 0.9625 - val_loss: 0.1080 - val_accuracy: 0.9656
# Epoch 21/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1156 - accuracy: 0.9650 - val_loss: 0.0816 - val_accuracy: 0.9785
# Epoch 22/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1113 - accuracy: 0.9667 - val_loss: 0.0979 - val_accuracy: 0.9685
# Epoch 23/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1207 - accuracy: 0.9625 - val_loss: 0.0794 - val_accuracy: 0.9814
# Epoch 24/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1147 - accuracy: 0.9675 - val_loss: 0.0709 - val_accuracy: 0.9885
# Epoch 25/50
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1108 - accuracy: 0.9678 - val_loss: 0.0827 - val_accuracy: 0.9857
# Epoch 26/50
# 125/125 [==============================] - 4s 29ms/step - loss: 0.1198 - accuracy: 0.9659 - val_loss: 0.0921 - val_accuracy: 0.9699
# Epoch 27/50
# 125/125 [==============================] - 4s 34ms/step - loss: 0.1108 - accuracy: 0.9668 - val_loss: 0.0651 - val_accuracy: 0.9857
# Epoch 28/50
# 125/125 [==============================] - 4s 30ms/step - loss: 0.1002 - accuracy: 0.9684 - val_loss: 0.0653 - val_accuracy: 0.9885
# Epoch 29/50
# 125/125 [==============================] - 3s 27ms/step - loss: 0.1145 - accuracy: 0.9675 - val_loss: 0.0886 - val_accuracy: 0.9771
# Epoch 30/50
# 125/125 [==============================] - 3s 26ms/step - loss: 0.0920 - accuracy: 0.9737 - val_loss: 0.0641 - val_accuracy: 0.9900
# Epoch 31/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0999 - accuracy: 0.9726 - val_loss: 0.0608 - val_accuracy: 0.9914
# Epoch 32/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1003 - accuracy: 0.9699 - val_loss: 0.0713 - val_accuracy: 0.9828
# Epoch 33/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.1143 - accuracy: 0.9670 - val_loss: 0.0659 - val_accuracy: 0.9900
# Epoch 34/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0901 - accuracy: 0.9737 - val_loss: 0.0743 - val_accuracy: 0.9828
# Epoch 35/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0999 - accuracy: 0.9736 - val_loss: 0.0606 - val_accuracy: 0.9900
# Epoch 36/50
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0856 - accuracy: 0.9774 - val_loss: 0.0542 - val_accuracy: 0.9928
# Epoch 37/50
# 125/125 [==============================] - 3s 22ms/step - loss: 0.0931 - accuracy: 0.9750 - val_loss: 0.0669 - val_accuracy: 0.9857
# Epoch 38/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.0872 - accuracy: 0.9774 - val_loss: 0.0606 - val_accuracy: 0.9857
# Epoch 39/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0999 - accuracy: 0.9692 - val_loss: 0.0581 - val_accuracy: 0.9885
# Epoch 40/50
# 125/125 [==============================] - 3s 21ms/step - loss: 0.0865 - accuracy: 0.9757 - val_loss: 0.0543 - val_accuracy: 0.9914
# Epoch 41/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0827 - accuracy: 0.9818 - val_loss: 0.0441 - val_accuracy: 0.9928
# Epoch 42/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0849 - accuracy: 0.9748 - val_loss: 0.0538 - val_accuracy: 0.9914
# Epoch 43/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0809 - accuracy: 0.9794 - val_loss: 0.0677 - val_accuracy: 0.9842
# Epoch 44/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0904 - accuracy: 0.9767 - val_loss: 0.0524 - val_accuracy: 0.9900
# Epoch 45/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0870 - accuracy: 0.9768 - val_loss: 0.0599 - val_accuracy: 0.9828
# Epoch 46/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0904 - accuracy: 0.9760 - val_loss: 0.0570 - val_accuracy: 0.9871
# Epoch 47/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.0865 - accuracy: 0.9771 - val_loss: 0.0488 - val_accuracy: 0.9943
# Epoch 48/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0896 - accuracy: 0.9759 - val_loss: 0.0516 - val_accuracy: 0.9914
# Epoch 49/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0833 - accuracy: 0.9771 - val_loss: 0.0625 - val_accuracy: 0.9900
# Epoch 50/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.0894 - accuracy: 0.9763 - val_loss: 0.0647 - val_accuracy: 0.9857

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.864406779661017

# %%
# increase range of shifting, shear, zoom

# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.04)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 18ms/step - loss: 0.5621 - accuracy: 0.7112 - val_loss: 0.2746 - val_accuracy: 0.9011
# Epoch 2/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3237 - accuracy: 0.8713 - val_loss: 0.2472 - val_accuracy: 0.9169
# Epoch 3/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2810 - accuracy: 0.8949 - val_loss: 0.2184 - val_accuracy: 0.9327
# Epoch 4/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2627 - accuracy: 0.9044 - val_loss: 0.2003 - val_accuracy: 0.9327
# Epoch 5/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2579 - accuracy: 0.8970 - val_loss: 0.1918 - val_accuracy: 0.9355
# Epoch 6/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2481 - accuracy: 0.9100 - val_loss: 0.1743 - val_accuracy: 0.9427
# Epoch 7/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2415 - accuracy: 0.9144 - val_loss: 0.1670 - val_accuracy: 0.9499
# Epoch 8/50
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2095 - accuracy: 0.9279 - val_loss: 0.1773 - val_accuracy: 0.9427
# Epoch 9/50
# 125/125 [==============================] - 3s 23ms/step - loss: 0.2246 - accuracy: 0.9164 - val_loss: 0.1609 - val_accuracy: 0.9470
# Epoch 10/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2149 - accuracy: 0.9222 - val_loss: 0.1529 - val_accuracy: 0.9513
# Epoch 11/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2043 - accuracy: 0.9256 - val_loss: 0.1614 - val_accuracy: 0.9470
# Epoch 12/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1983 - accuracy: 0.9280 - val_loss: 0.1426 - val_accuracy: 0.9542
# Epoch 13/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1921 - accuracy: 0.9356 - val_loss: 0.1274 - val_accuracy: 0.9613
# Epoch 14/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1866 - accuracy: 0.9343 - val_loss: 0.1382 - val_accuracy: 0.9542
# Epoch 15/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1953 - accuracy: 0.9308 - val_loss: 0.1390 - val_accuracy: 0.9585
# Epoch 16/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1712 - accuracy: 0.9435 - val_loss: 0.1253 - val_accuracy: 0.9642
# Epoch 17/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1747 - accuracy: 0.9407 - val_loss: 0.1315 - val_accuracy: 0.9527
# Epoch 18/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1677 - accuracy: 0.9428 - val_loss: 0.1025 - val_accuracy: 0.9685
# Epoch 19/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1711 - accuracy: 0.9418 - val_loss: 0.0940 - val_accuracy: 0.9756
# Epoch 20/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1610 - accuracy: 0.9448 - val_loss: 0.1228 - val_accuracy: 0.9613
# Epoch 21/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1433 - accuracy: 0.9566 - val_loss: 0.1123 - val_accuracy: 0.9656
# Epoch 22/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1471 - accuracy: 0.9533 - val_loss: 0.1029 - val_accuracy: 0.9728
# Epoch 23/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1627 - accuracy: 0.9465 - val_loss: 0.0882 - val_accuracy: 0.9728
# Epoch 24/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1499 - accuracy: 0.9540 - val_loss: 0.0986 - val_accuracy: 0.9728
# Epoch 25/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1479 - accuracy: 0.9545 - val_loss: 0.0970 - val_accuracy: 0.9742
# Epoch 26/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1557 - accuracy: 0.9524 - val_loss: 0.0945 - val_accuracy: 0.9699
# Epoch 27/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1386 - accuracy: 0.9592 - val_loss: 0.0839 - val_accuracy: 0.9771
# Epoch 28/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1489 - accuracy: 0.9539 - val_loss: 0.0868 - val_accuracy: 0.9728
# Epoch 29/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1360 - accuracy: 0.9537 - val_loss: 0.0943 - val_accuracy: 0.9670
# Epoch 30/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1418 - accuracy: 0.9554 - val_loss: 0.0890 - val_accuracy: 0.9785
# Epoch 31/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1347 - accuracy: 0.9594 - val_loss: 0.1030 - val_accuracy: 0.9713
# Epoch 32/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1226 - accuracy: 0.9651 - val_loss: 0.0826 - val_accuracy: 0.9785
# Epoch 33/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1285 - accuracy: 0.9616 - val_loss: 0.0795 - val_accuracy: 0.9799
# Epoch 34/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1264 - accuracy: 0.9625 - val_loss: 0.1003 - val_accuracy: 0.9685
# Epoch 35/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1300 - accuracy: 0.9594 - val_loss: 0.0831 - val_accuracy: 0.9728
# Epoch 36/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1225 - accuracy: 0.9623 - val_loss: 0.0685 - val_accuracy: 0.9828
# Epoch 37/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1241 - accuracy: 0.9623 - val_loss: 0.0773 - val_accuracy: 0.9814
# Epoch 38/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1199 - accuracy: 0.9599 - val_loss: 0.0843 - val_accuracy: 0.9771
# Epoch 39/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1184 - accuracy: 0.9647 - val_loss: 0.0935 - val_accuracy: 0.9771
# Epoch 40/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1194 - accuracy: 0.9668 - val_loss: 0.0691 - val_accuracy: 0.9828
# Epoch 41/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1275 - accuracy: 0.9615 - val_loss: 0.0662 - val_accuracy: 0.9857
# Epoch 42/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1183 - accuracy: 0.9657 - val_loss: 0.0688 - val_accuracy: 0.9857
# Epoch 43/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1211 - accuracy: 0.9637 - val_loss: 0.0648 - val_accuracy: 0.9857
# Epoch 44/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1212 - accuracy: 0.9636 - val_loss: 0.0612 - val_accuracy: 0.9814
# Epoch 45/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1134 - accuracy: 0.9677 - val_loss: 0.0977 - val_accuracy: 0.9756
# Epoch 46/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1142 - accuracy: 0.9702 - val_loss: 0.0829 - val_accuracy: 0.9756
# Epoch 47/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1076 - accuracy: 0.9717 - val_loss: 0.0659 - val_accuracy: 0.9842
# Epoch 48/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1052 - accuracy: 0.9695 - val_loss: 0.0770 - val_accuracy: 0.9799
# Epoch 49/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1198 - accuracy: 0.9655 - val_loss: 0.0843 - val_accuracy: 0.9756
# Epoch 50/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1043 - accuracy: 0.9692 - val_loss: 0.0639 - val_accuracy: 0.9900

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.9152542372881356

# %%
# also add scale_shift noise

# build the noise function
def addNoise(X):
    return add_scale_shift(add_gauss_noise(X, 0.04))

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 19ms/step - loss: 0.6194 - accuracy: 0.6755 - val_loss: 0.3997 - val_accuracy: 0.8309
# Epoch 2/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.4749 - accuracy: 0.7930 - val_loss: 0.2627 - val_accuracy: 0.8911
# Epoch 3/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3979 - accuracy: 0.8360 - val_loss: 0.2597 - val_accuracy: 0.9112
# Epoch 4/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3751 - accuracy: 0.8452 - val_loss: 0.2115 - val_accuracy: 0.9241
# Epoch 5/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3499 - accuracy: 0.8621 - val_loss: 0.2039 - val_accuracy: 0.9413
# Epoch 6/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3336 - accuracy: 0.8613 - val_loss: 0.1934 - val_accuracy: 0.9427
# Epoch 7/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3174 - accuracy: 0.8770 - val_loss: 0.1703 - val_accuracy: 0.9470
# Epoch 8/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3027 - accuracy: 0.8802 - val_loss: 0.1988 - val_accuracy: 0.9355
# Epoch 9/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2859 - accuracy: 0.8861 - val_loss: 0.1756 - val_accuracy: 0.9513
# Epoch 10/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2874 - accuracy: 0.8836 - val_loss: 0.1880 - val_accuracy: 0.9384
# Epoch 11/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2862 - accuracy: 0.8901 - val_loss: 0.1583 - val_accuracy: 0.9499
# Epoch 12/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2741 - accuracy: 0.8964 - val_loss: 0.1560 - val_accuracy: 0.9585
# Epoch 13/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2677 - accuracy: 0.8999 - val_loss: 0.1580 - val_accuracy: 0.9585
# Epoch 14/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2735 - accuracy: 0.8972 - val_loss: 0.1354 - val_accuracy: 0.9613
# Epoch 15/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2465 - accuracy: 0.9083 - val_loss: 0.1540 - val_accuracy: 0.9513
# Epoch 16/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2425 - accuracy: 0.9117 - val_loss: 0.1249 - val_accuracy: 0.9656
# Epoch 17/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2319 - accuracy: 0.9132 - val_loss: 0.1342 - val_accuracy: 0.9670
# Epoch 18/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2260 - accuracy: 0.9203 - val_loss: 0.1608 - val_accuracy: 0.9556
# Epoch 19/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2230 - accuracy: 0.9212 - val_loss: 0.1379 - val_accuracy: 0.9670
# Epoch 20/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2199 - accuracy: 0.9272 - val_loss: 0.1179 - val_accuracy: 0.9713
# Epoch 21/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2186 - accuracy: 0.9259 - val_loss: 0.1108 - val_accuracy: 0.9728
# Epoch 22/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2105 - accuracy: 0.9266 - val_loss: 0.1239 - val_accuracy: 0.9656
# Epoch 23/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2046 - accuracy: 0.9285 - val_loss: 0.1241 - val_accuracy: 0.9670
# Epoch 24/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2094 - accuracy: 0.9282 - val_loss: 0.0991 - val_accuracy: 0.9785
# Epoch 25/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1886 - accuracy: 0.9342 - val_loss: 0.1020 - val_accuracy: 0.9771
# Epoch 26/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1996 - accuracy: 0.9339 - val_loss: 0.1176 - val_accuracy: 0.9713
# Epoch 27/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1964 - accuracy: 0.9316 - val_loss: 0.1191 - val_accuracy: 0.9685
# Epoch 28/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2043 - accuracy: 0.9315 - val_loss: 0.1194 - val_accuracy: 0.9670
# Epoch 29/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1990 - accuracy: 0.9328 - val_loss: 0.1119 - val_accuracy: 0.9699
# Epoch 30/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1888 - accuracy: 0.9363 - val_loss: 0.1183 - val_accuracy: 0.9713
# Epoch 31/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1857 - accuracy: 0.9376 - val_loss: 0.1291 - val_accuracy: 0.9628
# Epoch 32/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1830 - accuracy: 0.9370 - val_loss: 0.1021 - val_accuracy: 0.9799
# Epoch 33/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1801 - accuracy: 0.9425 - val_loss: 0.1065 - val_accuracy: 0.9756
# Epoch 34/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1778 - accuracy: 0.9412 - val_loss: 0.0951 - val_accuracy: 0.9828
# Epoch 35/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1709 - accuracy: 0.9465 - val_loss: 0.0925 - val_accuracy: 0.9785
# Epoch 36/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1777 - accuracy: 0.9424 - val_loss: 0.1107 - val_accuracy: 0.9713
# Epoch 37/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1897 - accuracy: 0.9389 - val_loss: 0.0821 - val_accuracy: 0.9828
# Epoch 38/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1764 - accuracy: 0.9431 - val_loss: 0.0820 - val_accuracy: 0.9842
# Epoch 39/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1813 - accuracy: 0.9389 - val_loss: 0.0936 - val_accuracy: 0.9842
# Epoch 40/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1677 - accuracy: 0.9450 - val_loss: 0.1016 - val_accuracy: 0.9756
# Epoch 41/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1677 - accuracy: 0.9475 - val_loss: 0.1005 - val_accuracy: 0.9742
# Epoch 42/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1574 - accuracy: 0.9489 - val_loss: 0.1045 - val_accuracy: 0.9742
# Epoch 43/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1578 - accuracy: 0.9507 - val_loss: 0.0853 - val_accuracy: 0.9785
# Epoch 44/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1613 - accuracy: 0.9499 - val_loss: 0.0853 - val_accuracy: 0.9814
# Epoch 45/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1474 - accuracy: 0.9574 - val_loss: 0.1038 - val_accuracy: 0.9713
# Epoch 46/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1697 - accuracy: 0.9443 - val_loss: 0.0948 - val_accuracy: 0.9799
# Epoch 47/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1506 - accuracy: 0.9521 - val_loss: 0.0889 - val_accuracy: 0.9756
# Epoch 48/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1613 - accuracy: 0.9508 - val_loss: 0.0856 - val_accuracy: 0.9828
# Epoch 49/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1596 - accuracy: 0.9540 - val_loss: 0.0974 - val_accuracy: 0.9771
# Epoch 50/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1473 - accuracy: 0.9534 - val_loss: 0.0873 - val_accuracy: 0.9871

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.8728813559322034

# %%
# increase range of shifting, shear, zoom
# BEST

# build the noise function
def addNoise(X):
    return add_corrupt_noise(add_gauss_noise(X, 0.04))

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 19ms/step - loss: 0.6042 - accuracy: 0.6792 - val_loss: 0.2818 - val_accuracy: 0.8868
# Epoch 2/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3911 - accuracy: 0.8457 - val_loss: 0.2356 - val_accuracy: 0.9155
# Epoch 3/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3192 - accuracy: 0.8728 - val_loss: 0.2194 - val_accuracy: 0.9298
# Epoch 4/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2887 - accuracy: 0.8884 - val_loss: 0.2540 - val_accuracy: 0.9226
# Epoch 5/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2780 - accuracy: 0.8950 - val_loss: 0.2165 - val_accuracy: 0.9241
# Epoch 6/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2674 - accuracy: 0.8964 - val_loss: 0.2170 - val_accuracy: 0.9298
# Epoch 7/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2595 - accuracy: 0.9028 - val_loss: 0.1778 - val_accuracy: 0.9384
# Epoch 8/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2408 - accuracy: 0.9108 - val_loss: 0.1749 - val_accuracy: 0.9398
# Epoch 9/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2457 - accuracy: 0.9088 - val_loss: 0.2083 - val_accuracy: 0.9370
# Epoch 10/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2226 - accuracy: 0.9231 - val_loss: 0.1810 - val_accuracy: 0.9413
# Epoch 11/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2328 - accuracy: 0.9130 - val_loss: 0.1660 - val_accuracy: 0.9441
# Epoch 12/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2333 - accuracy: 0.9187 - val_loss: 0.1377 - val_accuracy: 0.9613
# Epoch 13/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2151 - accuracy: 0.9224 - val_loss: 0.1770 - val_accuracy: 0.9499
# Epoch 14/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2146 - accuracy: 0.9241 - val_loss: 0.1698 - val_accuracy: 0.9413
# Epoch 15/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2080 - accuracy: 0.9238 - val_loss: 0.1797 - val_accuracy: 0.9413
# Epoch 16/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2076 - accuracy: 0.9252 - val_loss: 0.1459 - val_accuracy: 0.9527
# Epoch 17/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2132 - accuracy: 0.9252 - val_loss: 0.1257 - val_accuracy: 0.9613
# Epoch 18/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2040 - accuracy: 0.9309 - val_loss: 0.1672 - val_accuracy: 0.9470
# Epoch 19/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2023 - accuracy: 0.9287 - val_loss: 0.1418 - val_accuracy: 0.9556
# Epoch 20/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1968 - accuracy: 0.9303 - val_loss: 0.1723 - val_accuracy: 0.9413
# Epoch 21/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1804 - accuracy: 0.9389 - val_loss: 0.1393 - val_accuracy: 0.9527
# Epoch 22/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1881 - accuracy: 0.9353 - val_loss: 0.1366 - val_accuracy: 0.9527
# Epoch 23/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1932 - accuracy: 0.9406 - val_loss: 0.1430 - val_accuracy: 0.9570
# Epoch 24/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1952 - accuracy: 0.9344 - val_loss: 0.1125 - val_accuracy: 0.9642
# Epoch 25/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1862 - accuracy: 0.9314 - val_loss: 0.1118 - val_accuracy: 0.9642
# Epoch 26/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1939 - accuracy: 0.9333 - val_loss: 0.1343 - val_accuracy: 0.9585
# Epoch 27/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1821 - accuracy: 0.9387 - val_loss: 0.1246 - val_accuracy: 0.9613
# Epoch 28/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1752 - accuracy: 0.9408 - val_loss: 0.1347 - val_accuracy: 0.9585
# Epoch 29/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1757 - accuracy: 0.9386 - val_loss: 0.1278 - val_accuracy: 0.9570
# Epoch 30/50
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1840 - accuracy: 0.9371 - val_loss: 0.1339 - val_accuracy: 0.9527
# Epoch 31/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1804 - accuracy: 0.9374 - val_loss: 0.1162 - val_accuracy: 0.9585
# Epoch 32/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1683 - accuracy: 0.9435 - val_loss: 0.1135 - val_accuracy: 0.9642
# Epoch 33/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1829 - accuracy: 0.9420 - val_loss: 0.1172 - val_accuracy: 0.9556
# Epoch 34/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1573 - accuracy: 0.9500 - val_loss: 0.1144 - val_accuracy: 0.9628
# Epoch 35/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1624 - accuracy: 0.9448 - val_loss: 0.1307 - val_accuracy: 0.9613
# Epoch 36/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1766 - accuracy: 0.9444 - val_loss: 0.1177 - val_accuracy: 0.9613
# Epoch 37/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1609 - accuracy: 0.9490 - val_loss: 0.1195 - val_accuracy: 0.9613
# Epoch 38/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1869 - accuracy: 0.9410 - val_loss: 0.1549 - val_accuracy: 0.9527
# Epoch 39/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1694 - accuracy: 0.9429 - val_loss: 0.1402 - val_accuracy: 0.9542
# Epoch 40/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1811 - accuracy: 0.9394 - val_loss: 0.1020 - val_accuracy: 0.9685
# Epoch 41/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1661 - accuracy: 0.9504 - val_loss: 0.1220 - val_accuracy: 0.9613
# Epoch 42/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1753 - accuracy: 0.9450 - val_loss: 0.1106 - val_accuracy: 0.9656
# Epoch 43/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1694 - accuracy: 0.9454 - val_loss: 0.1241 - val_accuracy: 0.9585
# Epoch 44/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1858 - accuracy: 0.9421 - val_loss: 0.1193 - val_accuracy: 0.9599
# Epoch 45/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1501 - accuracy: 0.9451 - val_loss: 0.0979 - val_accuracy: 0.9656
# Epoch 46/50
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1500 - accuracy: 0.9522 - val_loss: 0.1131 - val_accuracy: 0.9642
# Epoch 47/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1677 - accuracy: 0.9440 - val_loss: 0.1276 - val_accuracy: 0.9585
# Epoch 48/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1614 - accuracy: 0.9461 - val_loss: 0.0972 - val_accuracy: 0.9699
# Epoch 49/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1720 - accuracy: 0.9455 - val_loss: 0.1338 - val_accuracy: 0.9527
# Epoch 50/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1515 - accuracy: 0.9518 - val_loss: 0.0956 - val_accuracy: 0.9699

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.9036016949152542

# %%
# increase range of shifting, shear, zoom

# build the noise function
def addNoise(X):
    return add_gauss_noise(X, 0.1)

# build the data augmenter
datagen = ImageDataGenerator(
    rotation_range=10,         # image rotation
    width_shift_range=0.1,     # image shifting
    height_shift_range=0.1,    # image shifting
    shear_range=0.1,           # shear transformation
    zoom_range=0.1,            # zooming
    horizontal_flip=True,       # horizontal flipping
    preprocessing_function=addNoise,  # add per-pixel noise
    data_format='channels_last')

nn = trainNN(datagen)
# Out:
# /Users/abc/opt/anaconda3/envs/py38tflow2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 125/125 [==============================] - 3s 17ms/step - loss: 0.5732 - accuracy: 0.6978 - val_loss: 0.2431 - val_accuracy: 0.9183
# Epoch 2/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.3355 - accuracy: 0.8685 - val_loss: 0.2162 - val_accuracy: 0.9183
# Epoch 3/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2916 - accuracy: 0.8891 - val_loss: 0.2162 - val_accuracy: 0.9241
# Epoch 4/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2680 - accuracy: 0.9051 - val_loss: 0.2178 - val_accuracy: 0.9327
# Epoch 5/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2493 - accuracy: 0.9160 - val_loss: 0.1967 - val_accuracy: 0.9398
# Epoch 6/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2379 - accuracy: 0.9101 - val_loss: 0.2094 - val_accuracy: 0.9269
# Epoch 7/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2341 - accuracy: 0.9144 - val_loss: 0.1571 - val_accuracy: 0.9441
# Epoch 8/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2158 - accuracy: 0.9173 - val_loss: 0.1895 - val_accuracy: 0.9312
# Epoch 9/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2245 - accuracy: 0.9214 - val_loss: 0.1637 - val_accuracy: 0.9427
# Epoch 10/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2180 - accuracy: 0.9215 - val_loss: 0.1993 - val_accuracy: 0.9312
# Epoch 11/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1831 - accuracy: 0.9335 - val_loss: 0.1435 - val_accuracy: 0.9542
# Epoch 12/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2078 - accuracy: 0.9255 - val_loss: 0.1620 - val_accuracy: 0.9427
# Epoch 13/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1952 - accuracy: 0.9266 - val_loss: 0.1495 - val_accuracy: 0.9542
# Epoch 14/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1915 - accuracy: 0.9381 - val_loss: 0.1263 - val_accuracy: 0.9613
# Epoch 15/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1948 - accuracy: 0.9373 - val_loss: 0.1561 - val_accuracy: 0.9513
# Epoch 16/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1907 - accuracy: 0.9325 - val_loss: 0.1485 - val_accuracy: 0.9470
# Epoch 17/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1745 - accuracy: 0.9467 - val_loss: 0.1651 - val_accuracy: 0.9470
# Epoch 18/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1705 - accuracy: 0.9431 - val_loss: 0.1366 - val_accuracy: 0.9556
# Epoch 19/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1662 - accuracy: 0.9415 - val_loss: 0.1051 - val_accuracy: 0.9670
# Epoch 20/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1662 - accuracy: 0.9459 - val_loss: 0.1663 - val_accuracy: 0.9470
# Epoch 21/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1628 - accuracy: 0.9461 - val_loss: 0.1257 - val_accuracy: 0.9642
# Epoch 22/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1780 - accuracy: 0.9412 - val_loss: 0.1350 - val_accuracy: 0.9542
# Epoch 23/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1648 - accuracy: 0.9446 - val_loss: 0.1217 - val_accuracy: 0.9585
# Epoch 24/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1679 - accuracy: 0.9408 - val_loss: 0.1122 - val_accuracy: 0.9628
# Epoch 25/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1700 - accuracy: 0.9438 - val_loss: 0.1519 - val_accuracy: 0.9513
# Epoch 26/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1490 - accuracy: 0.9509 - val_loss: 0.1142 - val_accuracy: 0.9670
# Epoch 27/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1611 - accuracy: 0.9459 - val_loss: 0.1156 - val_accuracy: 0.9613
# Epoch 28/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1534 - accuracy: 0.9491 - val_loss: 0.0973 - val_accuracy: 0.9699
# Epoch 29/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1615 - accuracy: 0.9529 - val_loss: 0.1232 - val_accuracy: 0.9656
# Epoch 30/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1585 - accuracy: 0.9531 - val_loss: 0.0984 - val_accuracy: 0.9742
# Epoch 31/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1589 - accuracy: 0.9491 - val_loss: 0.0980 - val_accuracy: 0.9742
# Epoch 32/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1320 - accuracy: 0.9581 - val_loss: 0.1195 - val_accuracy: 0.9628
# Epoch 33/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1474 - accuracy: 0.9510 - val_loss: 0.1040 - val_accuracy: 0.9685
# Epoch 34/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1356 - accuracy: 0.9566 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 35/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1358 - accuracy: 0.9553 - val_loss: 0.0893 - val_accuracy: 0.9742
# Epoch 36/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1354 - accuracy: 0.9540 - val_loss: 0.0866 - val_accuracy: 0.9785
# Epoch 37/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1446 - accuracy: 0.9548 - val_loss: 0.1096 - val_accuracy: 0.9670
# Epoch 38/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1341 - accuracy: 0.9573 - val_loss: 0.0863 - val_accuracy: 0.9799
# Epoch 39/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1289 - accuracy: 0.9591 - val_loss: 0.0815 - val_accuracy: 0.9828
# Epoch 40/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1249 - accuracy: 0.9625 - val_loss: 0.0943 - val_accuracy: 0.9756
# Epoch 41/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1329 - accuracy: 0.9592 - val_loss: 0.0992 - val_accuracy: 0.9742
# Epoch 42/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1206 - accuracy: 0.9591 - val_loss: 0.0850 - val_accuracy: 0.9771
# Epoch 43/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1248 - accuracy: 0.9606 - val_loss: 0.0985 - val_accuracy: 0.9685
# Epoch 44/50
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1245 - accuracy: 0.9654 - val_loss: 0.0867 - val_accuracy: 0.9771
# Epoch 45/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1063 - accuracy: 0.9741 - val_loss: 0.0748 - val_accuracy: 0.9799
# Epoch 46/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1246 - accuracy: 0.9618 - val_loss: 0.1045 - val_accuracy: 0.9713
# Epoch 47/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1297 - accuracy: 0.9611 - val_loss: 0.0887 - val_accuracy: 0.9756
# Epoch 48/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1172 - accuracy: 0.9660 - val_loss: 0.0979 - val_accuracy: 0.9728
# Epoch 49/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1195 - accuracy: 0.9651 - val_loss: 0.0942 - val_accuracy: 0.9728
# Epoch 50/50
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1222 - accuracy: 0.9604 - val_loss: 0.0721 - val_accuracy: 0.9799

# %%
plot_history(history)
predY = argmax(nn.predict(testI, verbose=False), axis=-1)
acc = metrics.accuracy_score(testY, predY)
print("test accuracy:", acc)
# Out:
# test accuracy: 0.913135593220339

# %% [markdown]
# _How does CNN with data augmentation compare with your work in Tutorial 8?_
# - **INSERT YOUR ANSWER HERE**

# %% [markdown]
# - **INSERT YOUR ANSWER HERE**
# - Now accuracy is 0.91, which is better than MLP in Tutorial 8.

# %% [markdown]
# # Test image
# Now lets try your face detector on a real image.  Download the "nasa-small.png" image and put it in the same directory as your ipynb file.  The below code will load the image, crop out image patches and then extract features. (this may take a few minutes)

# %%
fname = "nasa-small.png"

# %%
# load image
testimg3 = skimage.io.imread(fname)

# convert to grayscale
testimg = skimage.color.rgb2gray(testimg3)
print(testimg.shape)
plt.imshow(testimg, cmap='gray')
# Out:
# (210, 480)
# <ipython-input-31-1ceedb6e5bb3>:5: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   testimg = skimage.color.rgb2gray(testimg3)

# %%
# step size for the sliding window
step = 4

# extract window patches with step size of 4
patches = skimage.util.view_as_windows(testimg, (19,19), step=step)
psize = patches.shape
# collapse the first 2 dimensions
patches2 = patches.reshape((psize[0]*psize[1], psize[2], psize[3], 1))
print(patches2.shape)

# histogram equalize patches (improves contrast)
#newI = empty(patches2.shape)
#for i in range(patches2.shape[0]):
#    newI[i,:,:] = skimage.exposure.equalize_hist(patches2[i,:,:])
newI = patches2
# Out:
# (5568, 19, 19, 1)

# %% [markdown]
# Now predict using your classifier.  The extracted images are in `newI`.

# %%
### YOUR CODE HERE
prednewY = argmax(nn.predict(newI), axis=-1)

# %% [markdown]
# Now we we will view the results on the image.  Use the below code. `prednewY` is the vector of predictions.

# %%
# reshape prediction to an image
imgY = prednewY.reshape(psize[0], psize[1])

# zoom back to image size
imgY2 = ndimage.interpolation.zoom(imgY, step, output=None, order=0)
# pad the top and left with half the window size
imgY2 = vstack((zeros((9, imgY2.shape[1])), imgY2))
imgY2 = hstack((zeros((imgY2.shape[0],9)), imgY2))
# pad right and bottom to same size as image
if (imgY2.shape[0] != testimg.shape[0]):
    imgY2 = vstack((imgY2, zeros((testimg.shape[0]-imgY2.shape[0], imgY2.shape[1]))))
if (imgY2.shape[1] != testimg.shape[1]):
    imgY2 = hstack((imgY2, zeros((imgY2.shape[0],testimg.shape[1]-imgY2.shape[1]))))
    
# show detections with image
#detimg = dstack(((0.5*imgY2+0.5)*testimg, 0.5*testimg, 0.5*testimg))
nimgY2 = 1-imgY2
tmp = nimgY2*testimg
detimg = dstack((imgY2+tmp, tmp, tmp))

# show it!
plt.figure(figsize=(9,9))
plt.subplot(2,1,1)
plt.imshow(imgY2, interpolation='nearest')
plt.title('detection map')
plt.subplot(2,1,2)
plt.imshow(detimg)
plt.title('image')
plt.axis('image')
# Out:
# (-0.5, 479.5, 209.5, -0.5)

# %% [markdown]
# _How did your face detector do compared to the last version?_
# - **INSERT YOUR ANSWER HERE**

# %% [markdown]
# - **INSERT YOUR ANSWER HERE**
# - detected more faces than MLP
# - similar number of FP

# %% [markdown]
# You can try it on your own images.  The faces should all be around 19x19 pixels though. We only used 1/8 of the training data. Try using more data to train it!
